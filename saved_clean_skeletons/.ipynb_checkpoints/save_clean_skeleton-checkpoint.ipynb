# %%
# % matplotlib inline
from neuprint import Client, skeleton
from neuprint import fetch_synapses, NeuronCriteria as NC, SynapseCriteria as SC
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import random
from os.path import isfile
from sklearn.linear_model import LogisticRegression
import time
from sklearn.decomposition import PCA
import statsmodels.api as sm

token_id = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdhcnJldHQuc2FnZXJAeWFsZS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hLS9BT2gxNEdpTGNqZXlHYWNnS3NPcTgzdDNfczBoTU5sQUtlTkljRzdxMkU5Rz1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgwMTAxNzUwNn0.dzq7Iy01JwSWbKq-Qvi8ov7Hwr0-ozpYeSnOsUD-Mx0"
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation
home_dir = '/home/gsager56/hemibrain/clean_mito_code'
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token=token_id)
neuron_quality = pd.read_csv(home_dir + '/saved_data/neuron_quality.csv')
neuron_quality_np = neuron_quality.to_numpy()
server = 'http://hemibrain-dvid.janelia.org'

# import utils file
spec = importlib.util.spec_from_file_location('utils', home_dir+'/util_files/utils.py')
utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(utils)

# import skel_clean_utils file
spec = importlib.util.spec_from_file_location('skel_clean_utils', home_dir+'/util_files/skel_clean_utils.py')
skel_clean_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(skel_clean_utils)

# import GLM_utils file
spec = importlib.util.spec_from_file_location('GLM_utils', home_dir+'/util_files/GLM_utils.py')
GLM_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(GLM_utils)

# import config file
spec = importlib.util.spec_from_file_location('config', home_dir+'/util_files/config.py')
config = importlib.util.module_from_spec(spec)
spec.loader.exec_module(config)

node_class_dict = config.node_class_dict
analyze_neurons  = config.analyze_neurons

# %%
# import skel_clean_utils file
spec = importlib.util.spec_from_file_location('skel_clean_utils', home_dir+'/util_files/skel_clean_utils.py')
skel_clean_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(skel_clean_utils)

std_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_std.csv').to_numpy()
mean_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_mean.csv').to_numpy()
betas = pd.read_csv(home_dir + '/saved_data/trivial_leaf_betas.csv').to_numpy()

for i_neuron in np.where( np.isin(neuron_quality_np[:,1], analyze_neurons) )[0]:
    t0 = time.time()
    bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    if isfile(skel_file) and not isfile(new_skel_file):
        old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
        node_classes, important_nodes = skel_clean_utils.classify_nodes(old_s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
        if node_classes is not None:
            s_pandas = pd.read_csv(skel_file)
            assert len(s_pandas) > 10
            s_pandas = skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
            skeleton.reorient_skeleton( s_pandas, rowId = important_nodes['root node'] )

            s_np = s_pandas.to_numpy()
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            keep_bool = np.ones( len(s_np), dtype=bool )
            for i_leaf, leaf_node in enumerate(leaf_nodes):
                leaf_idxs = utils.get_down_idxs(s_np, leaf_node, np.isin(s_np[:,0], branch_nodes))
                leaf_length = np.max( np.sqrt( np.sum( (s_np[leaf_idxs,:][:,[1,2,3]] - s_np[leaf_idxs[-1],[1,2,3]][np.newaxis,:])**2, axis=1) ) ) - s_np[leaf_idxs[-1],4]
                if leaf_length - (s_np[leaf_idxs[0],4]*2) <= (91.439 / 8):
                    keep_bool[ leaf_idxs[:-1] ] = False # this is a trivial leaf
            s_pandas = pd.DataFrame( data = s_np[ keep_bool ], columns = s_pandas.columns )
            s_np = s_pandas.to_numpy()
            
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
                    
            # eliminated nodes with the same coordinate
            del_idxs = [1]
            while len(del_idxs) > 0:
                skel_coords = s_np[:,[1,2,3]]
                row_cols = np.array( [ [] for _ in range(2) ] , dtype=int).T
                for row in range( len(s_np)-1 ):
                    cols = np.where( np.all(skel_coords[row].reshape((1,3)) == skel_coords[row+1:],axis=1) )[0]
                    if len(cols) >= 2:
                        # figure out who is connected to who
                        same_coord_idxs = np.append(row,cols+row+1)
                        same_coord_nodes = s_np[same_coord_idxs,0]
                        same_coord_down_nodes = s_np[same_coord_idxs,5]
                        if np.any( np.isin( same_coord_down_nodes, same_coord_nodes) ):
                            i_idx = np.where( np.isin( same_coord_down_nodes, same_coord_nodes) )[0][0]
                            j_idx = np.where( same_coord_down_nodes[i_idx] == same_coord_nodes )[0][0]
                            assert s_np[ same_coord_idxs[i_idx], 5] == s_np[ same_coord_idxs[j_idx], 0]

                            this_row, this_col = s_np[same_coord_idxs[[i_idx,j_idx]], 0]
                            if this_row not in row_cols and this_col not in row_cols:
                                row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                    elif len(cols)==1:
                        this_row = s_np[row,0]
                        this_col = s_np[cols[0]+row+1,0]
                        if this_row not in row_cols and this_col not in row_cols:
                            row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                assert len(np.unique(row_cols)) == len(row_cols.flatten())
                del_idxs = []
                for row_node, col_node in row_cols:
                    row = np.where( s_np[:,0] == row_node )[0][0]
                    col = np.where( s_np[:,0] == col_node )[0][0]

                    assert np.all( skel_coords[row] == skel_coords[col] )
                    if s_np[row,5] == s_np[col,0] or s_np[col,5] == s_np[row,0]:
                        if s_np[row,5] == s_np[col,0]:
                            up_idx, down_idx = row, col
                        elif s_np[col,5] == s_np[row,0]:
                            down_idx, up_idx = row, col
                        assert s_np[up_idx,5] == s_np[down_idx,0]

                        if np.sum( s_np[up_idx,0] == s_np[:,5] ) > 0:
                            # connect node(s) upstream of up_idx to down_idx 
                            for idx in np.where( s_np[up_idx,0] == s_np[:,5] )[0]:
                                s_pandas.at[idx, 'link'] = s_np[down_idx,0]
                        del_idxs.append( up_idx )
                if len(del_idxs) > 0:
                    s_np = s_np[ ~np.isin( np.arange(len(s_np)), del_idxs ) ]
                    s_pandas = pd.DataFrame( data = s_np, columns = s_pandas.columns )
            assert len(s_np) == len(s_pandas)
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
            
            # change direction of theta and phi to ensure they point down the skeleton
            new_cols = np.concatenate( [np.array(s_pandas.columns)[:6], ['distance'], np.array(s_pandas.columns)[6:] ] )
            s_pandas = skel_clean_utils.append_distance( s_pandas ) # create a distance field in the dataframe
            s_pandas = s_pandas.reindex(columns=new_cols)
            s_np = s_pandas.to_numpy()
            
            frac_wrong = 0.0
            for idx in range(len(s_np)):
                xyz = np.array( utils.spherical_2_cart(1, s_np[idx,7], s_np[idx,8]) )
                xyz = xyz / np.sqrt(np.sum(xyz**2))
                if s_np[idx,5] != -1:
                    down_idx = np.where(s_np[idx,5] == s_np[:,0] )[0][0]
                    down_xyz = s_np[ down_idx, [1,2,3]] - s_np[ idx, [1,2,3] ]
                    assert np.sqrt(np.sum(down_xyz**2)) > 0
                    down_xyz = down_xyz / np.sqrt(np.sum(down_xyz**2))
                    assert np.abs( np.sum(down_xyz * xyz) ) < 1.01, f'{down_xyz}, {xyz}, {np.sum(down_xyz * xyz)}'
                    if np.sum(down_xyz * xyz) < 0:
                        # xyz is pointed in the wrong direction
                        _, theta, phi = utils.cart_2_spherical( -xyz[0], -xyz[1], -xyz[2] )
                        s_np[idx,7] = theta
                        s_np[idx,8] = phi
                        frac_wrong += 1 / len(s_np)
            node_classes, important_nodes = skel_clean_utils.classify_nodes(s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
            s_pandas['node_classes'] = node_classes
            assert len(s_pandas) > 10
            s_pandas.to_csv(new_skel_file, index = False)
            print( f'Finished with {bodyId} {neuron_type}' )
print('Finished')
# Out:
# Finished with 1158187240 LC4
# Finished with 1158864995 LC4
# Exception ignored in: <ssl.SSLSocket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 57292), raddr=('206.241.0.102', 443)>
# ResourceWarning: unclosed <ssl.SSLSocket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 57292), raddr=('206.241.0.102', 443)>
# Exception ignored in: <ssl.SSLSocket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 57284), raddr=('206.241.0.102', 443)>
# ResourceWarning: unclosed <ssl.SSLSocket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 57284), raddr=('206.241.0.102', 443)>
# Finished with 1189559257 LC4
# Finished with 1218901359 LC4
# Finished with 1249932198 LC4
# Finished with 1251287671 LC4
# Finished with 1281303666 LC4
# Finished with 1405780725 LC4
# Finished with 1438524573 LC4
# Finished with 1466861327 LC4
# Finished with 1471601440 LC4
# Finished with 1498574596 LC4
# Finished with 1503999967 LC4
# Finished with 1562673627 LC4
# Finished with 1590979045 LC4
# Finished with 1621357756 LC4
# Finished with 1625080038 LC4
# Finished with 1688505620 LC4
# Finished with 1715459859 LC4
# Finished with 1745821751 LC4
# Finished with 1749258134 LC4
# Finished with 1782668028 LC4
# Finished with 1810956698 LC4
# Finished with 1809264255 LC4
# Finished with 1839288696 LC4
# Finished with 1840636280 LC4
# Finished with 1874035952 LC4
# Finished with 1876894387 LC4
# Finished with 1876898200 LC4
# Finished with 1877217777 LC4
# Finished with 1877930505 LC4
# Finished with 1877939213 LC4
# Finished with 1906496111 LC4
# Finished with 1907924777 LC4
# Finished with 1907933561 LC4
# Finished with 1906159299 LC4
# Finished with 1907510214 LC4
# Finished with 1907519001 LC4
# Finished with 1907571222 LC4
# Finished with 1907574944 LC4
# Finished with 1907578957 LC4
# Finished with 1907584319 LC4
# Finished with 1907587934 LC4
# Finished with 1907156409 LC4
# Finished with 1907169406 LC4
# Finished with 1938541380 LC4
# Finished with 1938207942 LC4
# Finished with 1937875810 LC4
# Finished with 1998922583 LC4
# Finished with 2121711447 LC4
# Finished with 2215161310 LC4
# Finished with 5812998136 LC4
# Finished with 5813061197 LC4
# Finished with 5813069053 LC4
# Finished with 5813069377 LC4
# Finished with 5813075607 LC4
# Finished with 5901215446 LC4
# Finished with 5812993692 LC4
# Finished with 1100558968 LC6
# Finished with 1168129036 LC6
# Finished with 1167438189 LC6
# Finished with 1167438283 LC6
# Finished with 1167438288 LC6
# Finished with 1167097258 LC6
# Finished with 1167783672 LC6
# Finished with 1168815348 LC6
# Finished with 1169847128 LC6
# Finished with 1199504502 LC6
# Finished with 1198132028 LC6
# Finished with 1198818609 LC6
# Finished with 1200541130 LC6
# Finished with 1200541193 LC6
# Finished with 1199850242 LC6
# Finished with 1199855170 LC6
# Finished with 1199159353 LC6
# Finished with 1199159635 LC6
# Finished with 1198477582 LC6
# Finished with 1198477590 LC6
# Finished with 1200195625 LC6
# Finished with 1201568417 LC6
# Finished with 1201568464 LC6
# Finished with 1200886425 LC6
# Finished with 1230190149 LC6
# Finished with 1231955783 LC6
# Finished with 1231955819 LC6
# Finished with 1231955849 LC6
# Finished with 1229849059 LC6
# Finished with 1230531237 LC6
# Finished with 1232249314 LC6
# Finished with 1232249325 LC6
# Finished with 1232257688 LC6
# Finished with 1232262131 LC6
# Finished with 1231614730 LC6
# Finished with 1231619255 LC6
# Finished with 1229507863 LC6
# Finished with 1232594718 LC6
# Finished with 1260879601 LC6
# Finished with 1261561493 LC6
# Finished with 1261565726 LC6
# Finished with 1259851971 LC6
# Finished with 1259852010 LC6
# Finished with 1261907163 LC6
# Finished with 1261220478 LC6
# Finished with 1261220560 LC6
# Finished with 1292670202 LC6
# Finished with 1293011130 LC6
# Finished with 1351317122 LC6
# Finished with 1534059927 LC6
# Finished with 1563389824 LC6
# Finished with 1627509034 LC6
# Finished with 1658199518 LC6
# Finished with 1720950695 LC6
# Finished with 5812986572 LC6
# Finished with 5812987690 LC6
# Finished with 5812989090 LC6
# Finished with 5812989550 LC6
# Finished with 5813048670 LC6
# Finished with 5813090856 LC6
# Finished with 1136744477 LC9
# Finished with 1166406326 LC9
# Finished with 1167438034 LC9
# Finished with 1199496144 LC9
# Finished with 1198818551 LC9
# Finished with 1198818618 LC9
# Finished with 1200536439 LC9
# Finished with 1200541165 LC9
# Finished with 1201227074 LC9
# Finished with 1201231377 LC9
# Finished with 1201231700 LC9
# Finished with 1201231760 LC9
# Finished with 1201231816 LC9
# Finished with 1201231826 LC9
# Finished with 1221289185 LC9
# Finished with 1200195649 LC9
# Finished with 1230190016 LC9
# Finished with 1231217536 LC9
# Finished with 1229162353 LC9
# Finished with 1229162381 LC9
# Finished with 1229166973 LC9
# Finished with 1230531125 LC9
# Finished with 1230535525 LC9
# Finished with 1232262105 LC9
# Finished with 1232266231 LC9
# Finished with 1232266303 LC9
# Finished with 1232266414 LC9
# Finished with 1232266616 LC9
# Finished with 1232288020 LC9
# Finished with 1229507904 LC9
# Finished with 1232603375 LC9
# Finished with 1232603386 LC9
# Finished with 1232607205 LC9
# Finished with 1232607449 LC9
# Finished with 1232607453 LC9
# Finished with 1232607542 LC9
# Finished with 1232634093 LC9
# Finished with 1253700547 LC9
# Finished with 1260879515 LC9
# Finished with 1262654081 LC9
# Finished with 1262654129 LC9
# Finished with 1263642185 LC9
# Finished with 1263646370 LC9
# Finished with 1263663953 LC9
# Finished with 1263663980 LC9
# Finished with 1263668331 LC9
# Finished with 1263668551 LC9
# Finished with 1262990404 LC9
# Finished with 1262994911 LC9
# Finished with 1263996477 LC9
# Finished with 1263309965 LC9
# Finished with 1263327135 LC9
# Finished with 1263327185 LC9
# Finished with 1263327214 LC9
# Finished with 1263331517 LC9
# Finished with 1288267063 LC9
# Finished with 1294362000 LC9
# Finished with 1294362035 LC9
# Finished with 1294362042 LC9
# Finished with 1294362092 LC9
# Finished with 1294366310 LC9
# Finished with 1294021030 LC9
# Finished with 1293006629 LC9
# Finished with 1319530284 LC9
# Finished with 1318956632 LC9
# Finished with 1380331849 LC9
# Finished with 1381704275 LC9
# Finished with 1404109050 LC9
# Finished with 1414776601 LC9
# Finished with 1413753838 LC9
# Finished with 1413766741 LC9
# Finished with 1445134193 LC9
# Finished with 1466511550 LC9
# Finished with 1469947718 LC9
# Finished with 1471307510 LC9
# Finished with 1470966783 LC9
# Finished with 1501660164 LC9
# Finished with 1501664753 LC9
# Finished with 1501665145 LC9
# Finished with 1502001218 LC9
# Finished with 1502342255 LC9
# Finished with 1532699404 LC9
# Finished with 1533036404 LC9
# Finished with 1540280212 LC9
# Finished with 1563393904 LC9
# Finished with 1595106149 LC9
# Finished with 1654120086 LC9
# Finished with 1747228863 LC9
# Finished with 1996202685 LC9
# Finished with 1995861983 LC9
# Finished with 5813056453 LC9
# Finished with 5813060834 LC9
# Finished with 5813062009 LC9
# Finished with 5813038196 LC9
# Finished with 5813038197 LC9
# Finished with 5813038198 LC9
# Finished with 5813038202 LC9
# Finished with 5813038203 LC9
# Finished with 5813038232 LC9
# Finished with 5813038238 LC9
# Finished with 5813038293 LC9
# Finished with 5813038294 LC9
# Finished with 5812988077 LC9
# Finished with 5812988098 LC9
# Finished with 5812988099 LC9
# Finished with 5812988109 LC9
# Finished with 5812988128 LC9
# Finished with 5812988132 LC9
# Finished with 5812988137 LC9
# Finished with 5812988514 LC9
# Finished with 5812988532 LC9
# Finished with 5812988568 LC9
# Finished with 5812988569 LC9
# Finished with 5812988573 LC9
# Finished with 5812988577 LC9
# Finished with 5813067943 LC9
# Finished with 5813067945 LC9
# Finished with 5812989059 LC9
# Finished with 5812989105 LC9
# Finished with 5812989120 LC9
# Finished with 5812989163 LC9
# Finished with 5812989593 LC9
# Finished with 5813044882 LC9
# Finished with 5813077658 LC9
# Finished with 5813077663 LC9
# Finished with 5813049193 LC9
# Finished with 5813050102 LC9
# Finished with 5813050145 LC9
# Finished with 5813054032 LC9
# Finished with 5813016577 LC9
# Finished with 5813016578 LC9
# Finished with 1017448980 LC10
# Finished with 1017090133 LC10
# Finished with 1017094185 LC10
# Finished with 1016749259 LC10
# Finished with 1016749264 LC10
# Finished with 1016753670 LC10
# Finished with 1016758041 LC10
# Finished with 1017781118 LC10
# Finished with 1017785388 LC10
# Finished with 1017789715 LC10
# Finished with 1017793356 LC10
# Finished with 1017797863 LC10
# Finished with 1016403512 LC10
# Finished with 1016403672 LC10
# Finished with 1016408273 LC10
# Finished with 1016408310 LC10
# Finished with 1017802759 LC10
# Finished with 1017802884 LC10
# Finished with 1018804242 LC10
# Finished with 1018458566 LC10
# Finished with 1018458715 LC10
# Finished with 1018462968 LC10
# Finished with 1018472039 LC10
# Finished with 1018476201 LC10
# Finished with 1048491559 LC10
# Finished with 1047779784 LC10
# Finished with 1047780090 LC10
# Finished with 1048837074 LC10
# Finished with 1048837669 LC10
# Finished with 1046734991 LC10
# Finished with 1048492326 LC10
# Finished with 1048492504 LC10
# Finished with 1047080740 LC10
# Finished with 1047784012 LC10
# Finished with 1047784109 LC10
# Finished with 1047784113 LC10
# Finished with 1047787967 LC10
# Finished with 1047106475 LC10
# Finished with 1047119615 LC10
# Finished with 1047123862 LC10
# Finished with 1049502699 LC10
# Finished with 1049506374 LC10
# Finished with 1049510640 LC10
# Finished with 1049511179 LC10
# Finished with 1049511270 LC10
# Finished with 1049838815 LC10
# Finished with 1049839301 LC10
# Finished with 1048470473 LC10
# Finished with 1049169888 LC10
# Finished with 1049174217 LC10
# Finished with 1048120973 LC10
# Finished with 1048125065 LC10
# Finished with 1048125254 LC10
# Finished with 1079859469 LC10
# Finished with 1079867909 LC10
# Finished with 1079872487 LC10
# Finished with 1079522281 LC10
# Finished with 1079527169 LC10
# Finished with 1079527389 LC10
# Finished with 1078111105 LC10
# Finished with 1077792194 LC10
# Finished with 1077792387 LC10
# Finished with 1077454826 LC10
# Finished with 1080878335 LC10
# Finished with 1080519686 LC10
# Finished with 1080528656 LC10
# Finished with 1080532771 LC10
# Finished with 1080537421 LC10
# Finished with 1080537608 LC10
# Finished with 1080537610 LC10
# Finished with 1080541803 LC10
# Finished with 1080541849 LC10
# Finished with 1080545525 LC10
# Finished with 1080196056 LC10
# Finished with 1080200318 LC10
# Finished with 1080200419 LC10
# Finished with 1080200438 LC10
# Finished with 1079841570 LC10
# Finished with 1080212848 LC10
# Finished with 1080213108 LC10
# Finished with 1079855015 LC10
# Finished with 1111217863 LC10
# Finished with 1107764430 LC10
# Finished with 1111243796 LC10
# Finished with 1111243870 LC10
# Finished with 1111244083 LC10
# Finished with 1111244201 LC10
# Finished with 1110885663 LC10
# Finished with 1110885932 LC10
# Finished with 1111248481 LC10
# Finished with 1110894595 LC10
# Finished with 1110903013 LC10
# Finished with 1110903093 LC10
# Finished with 1110906913 LC10
# Finished with 1110535962 LC10
# Finished with 1110536002 LC10
# Finished with 1110186452 LC10
# Finished with 1109841562 LC10
# Finished with 1110557531 LC10
# Finished with 1110562345 LC10
# Finished with 1110566098 LC10
# Finished with 1110566303 LC10
# Finished with 1110566383 LC10
# Finished with 1109167269 LC10
# Finished with 1109194016 LC10
# Finished with 1111917081 LC10
# Finished with 1111567676 LC10
# Finished with 1111572164 LC10
# Finished with 1111576163 LC10
# Finished with 1111580845 LC10
# Finished with 1138117141 LC10
# Finished with 1137085385 LC10
# Finished with 1137085556 LC10
# Finished with 1137763222 LC10
# Finished with 1136399017 LC10
# Finished with 1136399018 LC10
# Finished with 1141937695 LC10
# Finished with 1139153107 LC10
# Finished with 1139153136 LC10
# Finished with 1141251402 LC10
# Finished with 1141601145 LC10
# Finished with 1138807924 LC10
# Finished with 1136740119 LC10
# Finished with 1136744508 LC10
# Finished with 1136744536 LC10
# Finished with 1136744594 LC10
# Finished with 1136744598 LC10
# Finished with 1136744615 LC10
# Finished with 1141259920 LC10
# Finished with 1138812529 LC10
# Finished with 1140547788 LC10
# Finished with 1139835270 LC10
# Finished with 1139498661 LC10
# Finished with 1142598324 LC10
# Finished with 1142257556 LC10
# Finished with 1142266328 LC10
# Finished with 1166756335 LC10
# Finished with 1168120366 LC10
# Finished with 1169492931 LC10
# Finished with 1167429808 LC10
# Finished with 1167433954 LC10
# Finished with 1167433990 LC10
# Finished with 1167433991 LC10
# Finished with 1167434000 LC10
# Finished with 1169147605 LC10
# Finished with 1172623224 LC10
# Finished with 1172627154 LC10
# Finished with 1167092919 LC10
# Finished with 1199496243 LC10
# Finished with 1198123389 LC10
# Finished with 1198132022 LC10
# Finished with 1200523558 LC10
# Finished with 1200523569 LC10
# Finished with 1197791057 LC10
# Finished with 1198468674 LC10
# Finished with 1200182517 LC10
# Finished with 1200182520 LC10
# Finished with 1226084614 LC10
# Finished with 1231213221 LC10
# Finished with 1230526698 LC10
# Finished with 1228817231 LC10
# Finished with 1262602271 LC10
# Finished with 1261902646 LC10
# Finished with 1261902687 LC10
# Finished with 1261902715 LC10
# Finished with 1260192984 LC10
# Finished with 1282690130 LC10
# Finished with 1312368829 LC10
# Finished with 1291573712 LC10
# Finished with 1321222721 LC10
# Finished with 1347125913 LC10
# Finished with 1347470894 LC10
# Finished with 1346465519 LC10
# Finished with 1352598905 LC10
# Finished with 1376827225 LC10
# Finished with 1379549812 LC10
# Finished with 1383633527 LC10
# Finished with 1411262721 LC10
# Finished with 1439927802 LC10
# Finished with 1441590591 LC10
# Finished with 1438563366 LC10
# Finished with 1442293171 LC10
# Finished with 1442314421 LC10
# Finished with 1444006860 LC10
# Finished with 1471600919 LC10
# Finished with 1472996209 LC10
# Finished with 1505727476 LC10
# Finished with 1532699530 LC10
# Finished with 1533040625 LC10
# Finished with 1533040839 LC10
# Finished with 1536068485 LC10
# Finished with 1535410628 LC10
# Finished with 1563372679 LC10
# Finished with 1597456370 LC10
# Finished with 1599517714 LC10
# Finished with 1622740353 LC10
# Finished with 1625804723 LC10
# Finished with 1625804774 LC10
# Finished with 1657516638 LC10
# Finished with 1657517242 LC10
# Finished with 1661588290 LC10
# Finished with 1692614515 LC10
# Finished with 1692278031 LC10
# Finished with 1719237849 LC10
# Finished with 1719250390 LC10
# Finished with 1719591388 LC10
# Finished with 1746884134 LC10
# Finished with 1876105544 LC10
# Finished with 1935821486 LC10
# Finished with 2058932928 LC10
# Finished with 2088971332 LC10
# Finished with 2154767014 LC10
# Finished with 2185481747 LC10
# Finished with 5812996568 LC10
# Finished with 5813056280 LC10
# Finished with 5812997245 LC10
# Finished with 5813058307 LC10
# Finished with 5813109987 LC10
# Finished with 5813027631 LC10
# Finished with 5813031359 LC10
# Finished with 5813031440 LC10
# Finished with 5812983845 LC10
# Finished with 5813131327 LC10
# Finished with 5813035500 LC10
# Finished with 5813035545 LC10
# Finished with 5812986560 LC10
# Finished with 5812987709 LC10
# Finished with 5812987740 LC10
# Finished with 5813041453 LC10
# Finished with 5812990315 LC10
# Finished with 5812992408 LC10
# Finished with 5813041801 LC10
# Finished with 5813044569 LC10
# Finished with 5901214649 LC10
# Finished with 5812993252 LC10
# Finished with 5813047637 LC10
# Finished with 5813079014 LC10
# Finished with 5813048447 LC10
# Finished with 5813048450 LC10
# Finished with 5813048451 LC10
# Finished with 5813048452 LC10
# Finished with 5813048880 LC10
# Finished with 5813050604 LC10
# Finished with 5813081845 LC10
# Finished with 5813014401 LC10
# Finished with 5813015200 LC10
# Finished with 5813087952 LC10
# Finished with 5813015763 LC10
# Finished with 5813015764 LC10
# Finished with 5813016041 LC10
# Finished with 5813016057 LC10
# Finished with 5813016065 LC10
# Finished with 5813016076 LC10
# Finished with 5813016380 LC10
# Finished with 5813016381 LC10
# Finished with 5813016650 LC10
# Finished with 5813016652 LC10
# Finished with 5813016661 LC10
# Finished with 5813016987 LC10
# Finished with 5901118359 LC10
# Finished with 860892302 LC10
# Finished with 860896673 LC10
# Finished with 862252074 LC10
# Finished with 862256868 LC10
# Finished with 862265699 LC10
# Finished with 862265735 LC10
# Finished with 862269552 LC10
# Finished with 861915698 LC10
# Finished with 861915746 LC10
# Finished with 861920004 LC10
# Finished with 861920007 LC10
# Finished with 861920107 LC10
# Finished with 861920141 LC10
# Finished with 861565546 LC10
# Finished with 861570090 LC10
# Finished with 861574292 LC10
# Finished with 861574362 LC10
# Finished with 861574640 LC10
# Finished with 861574669 LC10
# Finished with 861578690 LC10
# Finished with 861578964 LC10
# Finished with 861579069 LC10
# Finished with 861583357 LC10
# Finished with 861583398 LC10
# Finished with 861588280 LC10
# Finished with 861224611 LC10
# Finished with 861229018 LC10
# Finished with 861229030 LC10
# Finished with 861229045 LC10
# Finished with 861233174 LC10
# Finished with 861233221 LC10
# Finished with 861233292 LC10
# Finished with 861233303 LC10
# Finished with 862602167 LC10
# Finished with 862606678 LC10
# Finished with 862610554 LC10
# Finished with 892963332 LC10
# Finished with 892963477 LC10
# Finished with 892963681 LC10
# Finished with 892963919 LC10
# Finished with 892964102 LC10
# Finished with 892968554 LC10
# Finished with 892968637 LC10
# Finished with 892600723 LC10
# Finished with 892604992 LC10
# Finished with 892605388 LC10
# Finished with 892609615 LC10
# Finished with 892613686 LC10
# Finished with 892622625 LC10
# Finished with 892622947 LC10
# Finished with 892623020 LC10
# Finished with 892255122 LC10
# Finished with 892259523 LC10
# Finished with 892259609 LC10
# Finished with 892268119 LC10
# Finished with 892268282 LC10
# Finished with 892268510 LC10
# Finished with 892268553 LC10
# Finished with 892273269 LC10
# Finished with 892277589 LC10
# Finished with 892277609 LC10
# Finished with 892281819 LC10
# Finished with 892282289 LC10
# Finished with 891918523 LC10
# Finished with 891918572 LC10
# Finished with 891922783 LC10
# Finished with 891922927 LC10
# Finished with 891923486 LC10
# Finished with 891927484 LC10
# Finished with 891927673 LC10
# Finished with 891927728 LC10
# Finished with 891927839 LC10
# Finished with 891931735 LC10
# Finished with 891935748 LC10
# Finished with 891935958 LC10
# Finished with 891936249 LC10
# Finished with 891582338 LC10
# Finished with 891586904 LC10
# Finished with 891595069 LC10
# Finished with 893632417 LC10
# Finished with 893633230 LC10
# Finished with 893637097 LC10
# Finished with 893642012 LC10
# Finished with 893645771 LC10
# Finished with 893287494 LC10
# Finished with 893287520 LC10
# Finished with 893287523 LC10
# Finished with 892950729 LC10
# Finished with 892958763 LC10
# Finished with 892959608 LC10
# Finished with 893305416 LC10
# Finished with 924344089 LC10
# Finished with 924344128 LC10
# Finished with 924348411 LC10
# Finished with 923977051 LC10
# Finished with 923994365 LC10
# Finished with 923994401 LC10
# Finished with 923998505 LC10
# Finished with 924002690 LC10
# Finished with 923636089 LC10
# Finished with 923640363 LC10
# Finished with 923644592 LC10
# Finished with 923644961 LC10
# Finished with 923648748 LC10
# Finished with 923657277 LC10
# Finished with 923661510 LC10
# Finished with 923661937 LC10
# Finished with 923303392 LC10
# Finished with 923321015 LC10
# Finished with 925344753 LC10
# Finished with 925003837 LC10
# Finished with 925004416 LC10
# Finished with 925008566 LC10
# Finished with 925017453 LC10
# Finished with 925017553 LC10
# Finished with 925021558 LC10
# Finished with 924326157 LC10
# Finished with 924326233 LC10
# Finished with 924681085 LC10
# Finished with 924689450 LC10
# Finished with 924335413 LC10
# Finished with 954010798 LC10
# Finished with 956384643 LC10
# Finished with 956043578 LC10
# Finished with 955698260 LC10
# Finished with 956397821 LC10
# Finished with 955702120 LC10
# Finished with 956056543 LC10
# Finished with 956060536 LC10
# Finished with 956060773 LC10
# Finished with 955715991 LC10
# Finished with 955365353 LC10
# Finished with 955365826 LC10
# Finished with 956082289 LC10
# Finished with 955020637 LC10
# Finished with 955024591 LC10
# Finished with 955024729 LC10
# Finished with 955374672 LC10
# Finished with 955374862 LC10
# Finished with 955378609 LC10
# Finished with 955383212 LC10
# Finished with 955383233 LC10
# Finished with 955029299 LC10
# Finished with 954675120 LC10
# Finished with 954692704 LC10
# Finished with 954342682 LC10
# Finished with 987419139 LC10
# Finished with 987419574 LC10
# Finished with 987419663 LC10
# Finished with 987424042 LC10
# Finished with 987424258 LC10
# Finished with 985347040 LC10
# Finished with 985347061 LC10
# Finished with 987091864 LC10
# Finished with 986396100 LC10
# Finished with 986396204 LC10
# Finished with 986758977 LC10
# Finished with 986759122 LC10
# Finished with 985369220 LC10
# Finished with 985377724 LC10
# Finished with 987104744 LC10
# Finished with 986763451 LC10
# Finished with 986763734 LC10
# Finished with 986767293 LC10
# Finished with 985386679 LC10
# Finished with 986404884 LC10
# Finished with 987116716 LC10
# Finished with 985036637 LC10
# Finished with 985710145 LC10
# Finished with 986059699 LC10
# Finished with 986059778 LC10
# Finished with 986063833 LC10
# Finished with 985714517 LC10
# Finished with 985722546 LC10
# Finished with 985722839 LC10
# Finished with 986422220 LC10
# Finished with 985731781 LC10
# Finished with 1158191562 LC11
# Finished with 1189904590 LC11
# Finished with 1188885499 LC11
# Finished with 1280971174 LC11
# Finished with 1342704830 LC11
# Finished with 1344055093 LC11
# Finished with 1384017738 LC11
# Finished with 1404778340 LC11
# Finished with 1410235604 LC11
# Finished with 1436188322 LC11
# Finished with 1440567395 LC11
# Finished with 1497875250 LC11
# Finished with 1499226615 LC11
# Finished with 1502635634 LC11
# Finished with 1528244653 LC11
# Finished with 1529923621 LC11
# Finished with 1532405813 LC11
# Finished with 1532410248 LC11
# Finished with 1533723752 LC11
# Finished with 1561304414 LC11
# Finished with 1562745969 LC11
# Finished with 1559948889 LC11
# Finished with 1563095512 LC11
# Finished with 1563436471 LC11
# Finished with 1563436478 LC11
# Finished with 1563436481 LC11
# Finished with 1563441250 LC11
# Finished with 1564753797 LC11
# Finished with 1565833050 LC11
# Finished with 1563782253 LC11
# Finished with 1562054982 LC11
# Finished with 1566169568 LC11
# Finished with 1566173885 LC11
# Finished with 1566173909 LC11
# Finished with 1566510982 LC11
# Finished with 1566511014 LC11
# Finished with 1566178615 LC11
# Finished with 1566519250 LC11
# Finished with 1566519741 LC11
# Finished with 1564075996 LC11
# Finished with 1566528972 LC11
# Finished with 1562400848 LC11
# Finished with 1562404815 LC11
# Finished with 1562404878 LC11
# Finished with 1564123481 LC11
# Finished with 1566851927 LC11
# Finished with 1566852153 LC11
# Finished with 1566856415 LC11
# Finished with 1565496703 LC11
# Finished with 1594121850 LC11
# Finished with 1594126040 LC11
# Finished with 1594126047 LC11
# Finished with 1594812379 LC11
# Finished with 1593784995 LC11
# Finished with 1652725444 LC11
# Finished with 1687874335 LC11
# Finished with 1747569967 LC11
# Finished with 1749270652 LC11
# Finished with 2121707030 LC11
# Finished with 5813056671 LC11
# Finished with 5812987890 LC11
# Finished with 5812988063 LC11
# Finished with 5812988296 LC11
# Finished with 5812990470 LC11
# Finished with 5812992814 LC11
# Finished with 1159551037 LC12
# Finished with 1343378332 LC12
# Finished with 1373734609 LC12
# Finished with 1376800240 LC12
# Finished with 1375768970 LC12
# Finished with 1377814057 LC12
# Finished with 1405107113 LC12
# Finished with 1435126790 LC12
# Finished with 1441589107 LC12
# Finished with 1441956741 LC12
# Finished with 1470237582 LC12
# Finished with 1471259890 LC12
# Finished with 1529928359 LC12
# Finished with 1530602252 LC12
# Finished with 1531975908 LC12
# Finished with 1534012511 LC12
# Finished with 1535718148 LC12
# Finished with 1563393697 LC12
# Finished with 1593743279 LC12
# Finished with 1621004685 LC12
# Finished with 1623072504 LC12
# Finished with 1620667669 LC12
# Finished with 1626140980 LC12
# Finished with 1627509673 LC12
# Finished with 1628140423 LC12
# Finished with 1628187260 LC12
# Finished with 1628192050 LC12
# Finished with 1654068522 LC12
# Finished with 1653390223 LC12
# Finished with 1656157224 LC12
# Finished with 1656157606 LC12
# Finished with 1656494569 LC12
# Finished with 1656834679 LC12
# Finished with 1656834849 LC12
# Finished with 1656839128 LC12
# Finished with 1654405306 LC12
# Finished with 1654405904 LC12
# Finished with 1657184761 LC12
# Finished with 1659226661 LC12
# Finished with 1657525390 LC12
# Finished with 1683756677 LC12
# Finished with 1686518948 LC12
# Finished with 1685776284 LC12
# Finished with 1690266485 LC12
# Finished with 1688892924 LC12
# Finished with 1688893211 LC12
# Finished with 1691574966 LC12
# Finished with 1691233928 LC12
# Finished with 1689242749 LC12
# Finished with 1690598004 LC12
# Finished with 1717153009 LC12
# Finished with 1719902535 LC12
# Finished with 1719928274 LC12
# Finished with 1721305372 LC12
# Finished with 1718863441 LC12
# Finished with 1721586536 LC12
# Finished with 1718917727 LC12
# Finished with 1720585281 LC12
# Finished with 1746546621 LC12
# Finished with 1748187188 LC12
# Finished with 1749957344 LC12
# Finished with 1747508899 LC12
# Finished with 1750621344 LC12
# Finished with 1750630587 LC12
# Finished with 1751943911 LC12
# Finished with 1753690864 LC12
# Finished with 1753691086 LC12
# Finished with 1753691232 LC12
# Finished with 1753695151 LC12
# Finished with 1753695182 LC12
# Finished with 1753695198 LC12
# Finished with 1753695251 LC12
# Finished with 1753695319 LC12
# Finished with 1753695328 LC12
# Finished with 1753695329 LC12
# Finished with 1753695387 LC12
# Finished with 1753695482 LC12
# Finished with 1753695554 LC12
# Finished with 1753695569 LC12
# Finished with 1753695576 LC12
# Finished with 1753695620 LC12
# Finished with 1753695737 LC12
# Finished with 1753695866 LC12
# Finished with 1753695941 LC12
# Finished with 1753696105 LC12
# Finished with 1753700376 LC12
# Finished with 1752671998 LC12
# Finished with 1751994423 LC12
# Finished with 1754028170 LC12
# Finished with 1754028266 LC12
# Finished with 1754032933 LC12
# Finished with 1754033051 LC12
# Finished with 1754033072 LC12
# Finished with 1754037055 LC12
# Finished with 1754369991 LC12
# Finished with 1754370241 LC12
# Finished with 1754370281 LC12
# Finished with 1754370313 LC12
# Finished with 1754370428 LC12
# Finished with 1754374121 LC12
# Finished with 1753354492 LC12
# Finished with 1753354584 LC12
# Finished with 1753354657 LC12
# Finished with 1753354671 LC12
# Finished with 1753358619 LC12
# Finished with 1753358914 LC12
# Finished with 1753358965 LC12
# Finished with 1753359080 LC12
# Finished with 1753359088 LC12
# Finished with 1753359129 LC12
# Finished with 1753359145 LC12
# Finished with 1753359149 LC12
# Finished with 1753359235 LC12
# Finished with 1753359267 LC12
# Finished with 1753359276 LC12
# Finished with 1753359328 LC12
# Finished with 1754042300 LC12
# Finished with 1754374486 LC12
# Finished with 1753363739 LC12
# Finished with 1754715778 LC12
# Finished with 1754715820 LC12
# Finished with 1754715852 LC12
# Finished with 1751257274 LC12
# Finished with 1782006592 LC12
# Finished with 1784052291 LC12
# Finished with 1784052503 LC12
# Finished with 1784057153 LC12
# Finished with 1784057323 LC12
# Finished with 1783348805 LC12
# Finished with 1784725840 LC12
# Finished with 1784726510 LC12
# Finished with 1784730276 LC12
# Finished with 1784730808 LC12
# Finished with 1784734375 LC12
# Finished with 1784735157 LC12
# Finished with 1784738845 LC12
# Finished with 1784739629 LC12
# Finished with 1785058604 LC12
# Finished with 1785399685 LC12
# Finished with 1785400064 LC12
# Finished with 1785403942 LC12
# Finished with 1785067268 LC12
# Finished with 1785067611 LC12
# Finished with 1785076238 LC12
# Finished with 1784389055 LC12
# Finished with 1784389414 LC12
# Finished with 1784389603 LC12
# Finished with 1784389638 LC12
# Finished with 1784393707 LC12
# Finished with 1784393992 LC12
# Finished with 1784397838 LC12
# Finished with 1784398229 LC12
# Finished with 1784398302 LC12
# Finished with 1784398319 LC12
# Finished with 1784398330 LC12
# Finished with 1784402781 LC12
# Finished with 1785408076 LC12
# Finished with 1785408384 LC12
# Finished with 1785408640 LC12
# Finished with 1785412639 LC12
# Finished with 1785417481 LC12
# Finished with 1783025171 LC12
# Finished with 1783029895 LC12
# Finished with 1783038540 LC12
# Finished with 1785740683 LC12
# Finished with 1785740974 LC12
# Finished with 1785745638 LC12
# Finished with 1784441060 LC12
# Finished with 1785753951 LC12
# Finished with 1786091589 LC12
# Finished with 1815773781 LC12
# Finished with 1815773916 LC12
# Finished with 1815778676 LC12
# Finished with 1813373584 LC12
# Finished with 1814751048 LC12
# Finished with 1814759163 LC12
# Finished with 1814759464 LC12
# Finished with 1816788474 LC12
# Finished with 1815432882 LC12
# Finished with 1815087643 LC12
# Finished with 1815096511 LC12
# Finished with 1815713979 LC12
# Finished with 1816106457 LC12
# Finished with 1816114845 LC12
# Finished with 1816115219 LC12
# Finished with 1815769330 LC12
# Finished with 1815769521 LC12
# Finished with 1816456312 LC12
# Finished with 1847145780 LC12
# Finished with 1846135022 LC12
# Finished with 1846800094 LC12
# Finished with 1846812834 LC12
# Finished with 1847819222 LC12
# Finished with 1876803839 LC12
# Finished with 1873078321 LC12
# Finished with 1878543927 LC12
# Finished with 1906836822 LC12
# Finished with 1907518969 LC12
# Finished with 1905110758 LC12
# Finished with 1934470099 LC12
# Finished with 1939244343 LC12
# Finished with 1935843067 LC12
# Finished with 5812995680 LC12
# Finished with 5812997387 LC12
# Finished with 5813107445 LC12
# Finished with 5813062654 LC12
# Finished with 5901203099 LC12
# Finished with 5901203642 LC12
# Finished with 5812983999 LC12
# Finished with 5813034099 LC12
# Finished with 5813034101 LC12
# Finished with 5813038320 LC12
# Finished with 5813038879 LC12
# Finished with 5813038880 LC12
# Finished with 5813039336 LC12
# Finished with 5901211214 LC12
# Finished with 5812990959 LC12
# Finished with 5812991748 LC12
# Finished with 5812992842 LC12
# Finished with 5812992935 LC12
# Finished with 5812993220 LC12
# Finished with 5812993314 LC12
# Finished with 5812993678 LC12
# Finished with 5813048920 LC12
# Finished with 1252337098 LC13
# Finished with 1316103996 LC13
# Finished with 1374784418 LC13
# Finished with 1376809072 LC13
# Finished with 1379541865 LC13
# Finished with 1406928592 LC13
# Finished with 1407610974 LC13
# Finished with 1405824057 LC13
# Finished with 1407269137 LC13
# Finished with 1407269144 LC13
# Finished with 1407269278 LC13
# Finished with 1407269350 LC13
# Finished with 1437959040 LC13
# Finished with 1438299718 LC13
# Finished with 1438300188 LC13
# Finished with 1438300285 LC13
# Finished with 1438300417 LC13
# Finished with 1438304464 LC13
# Finished with 1438304477 LC13
# Finished with 1438304554 LC13
# Finished with 1438304573 LC13
# Finished with 1438304604 LC13
# Finished with 1438304646 LC13
# Finished with 1434798670 LC13
# Finished with 1468993852 LC13
# Finished with 1468994014 LC13
# Finished with 1468998393 LC13
# Finished with 1469331067 LC13
# Finished with 1501976890 LC13
# Finished with 1499683287 LC13
# Finished with 1500020535 LC13
# Finished with 1500024261 LC13
# Finished with 1500028932 LC13
# Finished with 1500361710 LC13
# Finished with 1500369887 LC13
# Finished with 1500369943 LC13
# Finished with 1500373828 LC13
# Finished with 1529933124 LC13
# Finished with 1533088563 LC13
# Finished with 1530704811 LC13
# Finished with 1531059000 LC13
# Finished with 1531063618 LC13
# Finished with 1531391407 LC13
# Finished with 1531676892 LC13
# Finished with 1560661080 LC13
# Finished with 1560311044 LC13
# Finished with 1564472872 LC13
# Finished with 1624418395 LC13
# Finished with 1655458719 LC13
# Finished with 1842682500 LC13
# Finished with 1873086684 LC13
# Finished with 1937501015 LC13
# Finished with 1933433614 LC13
# Finished with 1967508592 LC13
# Finished with 2027880999 LC13
# Finished with 2090681039 LC13
# Finished with 2121685030 LC13
# Finished with 2121690154 LC13
# Finished with 2154442557 LC13
# Finished with 2181048794 LC13
# Finished with 2277917069 LC13
# Finished with 2309297730 LC13
# Finished with 5812996576 LC13
# Finished with 5813102910 LC13
# Finished with 5813023645 LC13
# Finished with 5901202018 LC13
# Finished with 5812988175 LC13
# Finished with 5812991436 LC13
# Finished with 5812991952 LC13
# Finished with 5813078183 LC13
# Finished with 5813014491 LC13
# Finished with 1158191887 LC14
# Finished with 1255405703 LC14
# Finished with 1316086414 LC14
# Finished with 1377845289 LC14
# Finished with 1408880450 LC14
# Finished with 1441949046 LC14
# Finished with 1470950640 LC14
# Finished with 1533338992 LC14
# Finished with 5813033742 LC14
# Finished with 5812989312 LC14
# Finished with 5813054748 LC14
# Finished with 1190591244 LC15
# Finished with 1222302866 LC15
# Finished with 1252337419 LC15
# Finished with 1256835428 LC15
# Finished with 1343732093 LC15
# Finished with 1346460600 LC15
# Finished with 1466516076 LC15
# Finished with 1469240274 LC15
# Finished with 1502304455 LC15
# Finished with 1507787264 LC15
# Finished with 1507787627 LC15
# Finished with 1507445759 LC15
# Finished with 1507446240 LC15
# Finished with 1507781967 LC15
# Finished with 1508118468 LC15
# Finished with 1508118556 LC15
# Finished with 1508118563 LC15
# Finished with 1536783850 LC15
# Finished with 1536783933 LC15
# Finished with 1536788564 LC15
# Finished with 1537130629 LC15
# Finished with 1536446911 LC15
# Finished with 1536451903 LC15
# Finished with 1536452097 LC15
# Finished with 1536793384 LC15
# Finished with 1537456949 LC15
# Finished with 1537793884 LC15
# Finished with 1537797832 LC15
# Finished with 1537798206 LC15
# Finished with 1537466874 LC15
# Finished with 1537803404 LC15
# Finished with 1537803538 LC15
# Finished with 1537803564 LC15
# Finished with 1538135324 LC15
# Finished with 1538135372 LC15
# Finished with 1538471582 LC15
# Finished with 1538476539 LC15
# Finished with 1567482594 LC15
# Finished with 1567145429 LC15
# Finished with 1567482299 LC15
# Finished with 1745510607 LC15
# Finished with 1750243366 LC15
# Finished with 1810944084 LC15
# Finished with 1870993614 LC15
# Finished with 1905093495 LC15
# Finished with 1908524574 LC15
# Finished with 1970253290 LC15
# Finished with 2026862112 LC15
# Finished with 2062689505 LC15
# Finished with 2249598591 LC15
# Finished with 2246861609 LC15
# Finished with 5812998950 LC15
# Finished with 5813062759 LC15
# Finished with 5813130156 LC15
# Finished with 5813038182 LC15
# Finished with 5812989160 LC15
# Finished with 5812989784 LC15
# Finished with 5813045646 LC15
# Finished with 5813078658 LC15
# Finished with 5813016851 LC15
# Finished with 1256830582 LC16
# Finished with 1254037524 LC16
# Finished with 1289229572 LC16
# Finished with 1289229616 LC16
# Finished with 1289229674 LC16
# Finished with 1289229700 LC16
# Finished with 1289233656 LC16
# Finished with 1289233753 LC16
# Finished with 1289233760 LC16
# Finished with 1289233847 LC16
# Finished with 1289233864 LC16
# Finished with 1289234133 LC16
# Finished with 1289238130 LC16
# Finished with 1289238358 LC16
# Finished with 1289238742 LC16
# Finished with 1289238841 LC16
# Finished with 1289238970 LC16
# Finished with 1289238972 LC16
# Finished with 1289239054 LC16
# Finished with 1288893454 LC16
# Finished with 1288893503 LC16
# Finished with 1288893591 LC16
# Finished with 1288893609 LC16
# Finished with 1288893672 LC16
# Finished with 1288897699 LC16
# Finished with 1288897930 LC16
# Finished with 1289574643 LC16
# Finished with 1289574672 LC16
# Finished with 1317457971 LC16
# Finished with 1319246910 LC16
# Finished with 1319251041 LC16
# Finished with 1319911391 LC16
# Finished with 1319915731 LC16
# Finished with 1319915822 LC16
# Finished with 1319919608 LC16
# Finished with 1319919610 LC16
# Finished with 1319919698 LC16
# Finished with 1319919814 LC16
# Finished with 1319919918 LC16
# Finished with 1319923967 LC16
# Finished with 1319927345 LC16
# Finished with 1319927827 LC16
# Finished with 1319928209 LC16
# Finished with 1319928264 LC16
# Finished with 1319932206 LC16
# Finished with 1320263998 LC16
# Finished with 1319578883 LC16
# Finished with 1319579283 LC16
# Finished with 1319579391 LC16
# Finished with 1319583082 LC16
# Finished with 1319583148 LC16
# Finished with 1319583205 LC16
# Finished with 1320273763 LC16
# Finished with 1319586861 LC16
# Finished with 1319587003 LC16
# Finished with 1319587380 LC16
# Finished with 1319591242 LC16
# Finished with 1319591297 LC16
# Finished with 1319591442 LC16
# Finished with 1319591480 LC16
# Finished with 1319591563 LC16
# Finished with 1319591655 LC16
# Finished with 1319591678 LC16
# Finished with 1319591709 LC16
# Finished with 1351282553 LC16
# Finished with 1350937208 LC16
# Finished with 1350945956 LC16
# Finished with 1350272746 LC16
# Finished with 1350613510 LC16
# Finished with 1350626363 LC16
# Finished with 1412989088 LC16
# Finished with 1412989266 LC16
# Finished with 1443682977 LC16
# Finished with 1444024342 LC16
# Finished with 1505412068 LC16
# Finished with 1528926565 LC16
# Finished with 1683440362 LC16
# Finished with 1750587711 LC16
# Finished with 1808267138 LC16
# Finished with 1908528698 LC16
# Finished with 1997498177 LC16
# Finished with 2000900137 LC16
# Finished with 5813133779 LC16
# Finished with 1158877703 LC17
# Finished with 1158877783 LC17
# Finished with 1189567690 LC17
# Finished with 1190250299 LC17
# Finished with 1221280490 LC17
# Finished with 1221285175 LC17
# Finished with 1219592090 LC17
# Finished with 1250277991 LC17
# Finished with 1313702895 LC17
# Finished with 1347126097 LC17
# Finished with 1345079276 LC17
# Finished with 1347812305 LC17
# Finished with 1348153557 LC17
# Finished with 1375769049 LC17
# Finished with 1405788552 LC17
# Finished with 1437165487 LC17
# Finished with 1435822283 LC17
# Finished with 1466844031 LC17
# Finished with 1467859487 LC17
# Finished with 1473648518 LC17
# Finished with 1471607030 LC17
# Finished with 1472965897 LC17
# Finished with 1471610338 LC17
# Finished with 1473332777 LC17
# Finished with 1497200791 LC17
# Finished with 1530606252 LC17
# Finished with 1528577476 LC17
# Finished with 1534694621 LC17
# Finished with 1561301125 LC17
# Finished with 1562707421 LC17
# Finished with 1563355501 LC17
# Finished with 1565729476 LC17
# Finished with 1589972966 LC17
# Finished with 1593012939 LC17
# Finished with 1621008677 LC17
# Finished with 1622360309 LC17
# Finished with 1629163100 LC17
# Finished with 1628528573 LC17
# Finished with 1655474822 LC17
# Finished with 1656153289 LC17
# Finished with 1656834653 LC17
# Finished with 1659515529 LC17
# Finished with 1654413566 LC17
# Finished with 1658881325 LC17
# Finished with 1684443103 LC17
# Finished with 1689187126 LC17
# Finished with 1689200671 LC17
# Finished with 1687831632 LC17
# Finished with 1689915765 LC17
# Finished with 1689239035 LC17
# Finished with 1714113234 LC17
# Finished with 1714791446 LC17
# Finished with 1722307233 LC17
# Finished with 1750251452 LC17
# Finished with 1751666374 LC17
# Finished with 1747181914 LC17
# Finished with 1747518018 LC17
# Finished with 1750622215 LC17
# Finished with 1753670596 LC17
# Finished with 1752672460 LC17
# Finished with 1754019541 LC17
# Finished with 1751262627 LC17
# Finished with 1776865370 LC17
# Finished with 1781324410 LC17
# Finished with 1781333405 LC17
# Finished with 1782680353 LC17
# Finished with 1783361972 LC17
# Finished with 1782318275 LC17
# Finished with 1783690466 LC17
# Finished with 1807572051 LC17
# Finished with 1814410124 LC17
# Finished with 1812363713 LC17
# Finished with 1813382259 LC17
# Finished with 1814729223 LC17
# Finished with 1813028777 LC17
# Finished with 1814031575 LC17
# Finished with 1814055949 LC17
# Finished with 1814060070 LC17
# Finished with 1818473569 LC17
# Finished with 1817107934 LC17
# Finished with 1817108009 LC17
# Finished with 1817112807 LC17
# Finished with 1817112855 LC17
# Finished with 1817113079 LC17
# Finished with 1817444555 LC17
# Finished with 1817444670 LC17
# Finished with 1817448659 LC17
# Finished with 1817448921 LC17
# Finished with 1817448971 LC17
# Finished with 1817449059 LC17
# Finished with 1817449116 LC17
# Finished with 1817449229 LC17
# Finished with 1817449236 LC17
# Finished with 1817452948 LC17
# Finished with 1817453065 LC17
# Finished with 1817453257 LC17
# Finished with 1817453557 LC17
# Finished with 1817457808 LC17
# Finished with 1817457847 LC17
# Finished with 1817457984 LC17
# Finished with 1817457987 LC17
# Finished with 1817458052 LC17
# Finished with 1817458164 LC17
# Finished with 1817785661 LC17
# Finished with 1817785682 LC17
# Finished with 1817786077 LC17
# Finished with 1817790176 LC17
# Finished with 1817790222 LC17
# Finished with 1817790281 LC17
# Finished with 1817790409 LC17
# Finished with 1817794820 LC17
# Finished with 1818122205 LC17
# Finished with 1817799390 LC17
# Finished with 1818136404 LC17
# Finished with 1845772658 LC17
# Finished with 1849161407 LC17
# Finished with 1849166071 LC17
# Finished with 1847806203 LC17
# Finished with 1847806275 LC17
# Finished with 1847810811 LC17
# Finished with 1847815147 LC17
# Finished with 1849174879 LC17
# Finished with 1849178917 LC17
# Finished with 1849179266 LC17
# Finished with 1849183960 LC17
# Finished with 1844421716 LC17
# Finished with 1849503142 LC17
# Finished with 1849507321 LC17
# Finished with 1848138779 LC17
# Finished with 1848143184 LC17
# Finished with 1848151236 LC17
# Finished with 1848151571 LC17
# Finished with 1849520324 LC17
# Finished with 1848151877 LC17
# Finished with 1848156241 LC17
# Finished with 1848483949 LC17
# Finished with 1848492258 LC17
# Finished with 1848492714 LC17
# Finished with 1848496662 LC17
# Finished with 1848820426 LC17
# Finished with 1848824817 LC17
# Finished with 1848828925 LC17
# Finished with 1848837843 LC17
# Finished with 1876820783 LC17
# Finished with 1875124235 LC17
# Finished with 1875460978 LC17
# Finished with 1879519066 LC17
# Finished with 1878845226 LC17
# Finished with 1878845629 LC17
# Finished with 1879877415 LC17
# Finished with 1880887003 LC17
# Finished with 1880209425 LC17
# Finished with 1908865507 LC17
# Finished with 1912600163 LC17
# Finished with 1937193993 LC17
# Finished with 1939904964 LC17
# Finished with 1974682390 LC17
# Finished with 2029624973 LC17
# Finished with 2245501457 LC17
# Finished with 5812998833 LC17
# Finished with 5812999009 LC17
# Finished with 5813060163 LC17
# Finished with 5813034336 LC17
# Finished with 5813038918 LC17
# Finished with 5813039410 LC17
# Finished with 5812988086 LC17
# Finished with 5813068239 LC17
# Finished with 5812991769 LC17
# Finished with 5812992219 LC17
# Finished with 5812992468 LC17
# Finished with 5812993994 LC17
# Finished with 1158191622 LC18
# Finished with 1158536635 LC18
# Finished with 1188548330 LC18
# Finished with 1220607239 LC18
# Finished with 1249936614 LC18
# Finished with 1342022174 LC18
# Finished with 1374413370 LC18
# Finished with 1437156900 LC18
# Finished with 1501323994 LC18
# Finished with 1559270886 LC18
# Finished with 1560289552 LC18
# Finished with 1589969344 LC18
# Finished with 1594092024 LC18
# Finished with 1593401239 LC18
# Finished with 1621003660 LC18
# Finished with 1651701899 LC18
# Finished with 1655475659 LC18
# Finished with 1655479310 LC18
# Finished with 1656157451 LC18
# Finished with 1656157978 LC18
# Finished with 1656839788 LC18
# Finished with 1657180509 LC18
# Finished with 1687874488 LC18
# Finished with 1688211725 LC18
# Finished with 1714134140 LC18
# Finished with 1714138461 LC18
# Finished with 1714479649 LC18
# Finished with 1717208400 LC18
# Finished with 1722000794 LC18
# Finished with 1722000978 LC18
# Finished with 1718231248 LC18
# Finished with 1722005013 LC18
# Finished with 1722005199 LC18
# Finished with 1717894837 LC18
# Finished with 1717899693 LC18
# Finished with 1717899720 LC18
# Finished with 1718918218 LC18
# Finished with 1718918235 LC18
# Finished with 1718922502 LC18
# Finished with 1722670151 LC18
# Finished with 1722670397 LC18
# Finished with 1722670422 LC18
# Finished with 1721659644 LC18
# Finished with 1722682692 LC18
# Finished with 1723015266 LC18
# Finished with 1723019231 LC18
# Finished with 1722333142 LC18
# Finished with 1722333392 LC18
# Finished with 1722333743 LC18
# Finished with 1722336465 LC18
# Finished with 1722336935 LC18
# Finished with 1722337568 LC18
# Finished with 1723023890 LC18
# Finished with 1723024021 LC18
# Finished with 1722338027 LC18
# Finished with 1722341820 LC18
# Finished with 1722342048 LC18
# Finished with 1722346327 LC18
# Finished with 1722346362 LC18
# Finished with 1722346846 LC18
# Finished with 1745860329 LC18
# Finished with 1746884233 LC18
# Finished with 1751321418 LC18
# Finished with 1751325674 LC18
# Finished with 1751330026 LC18
# Finished with 1750980224 LC18
# Finished with 1750984451 LC18
# Finished with 1749611399 LC18
# Finished with 1749620832 LC18
# Finished with 1752694591 LC18
# Finished with 1752699920 LC18
# Finished with 1754041168 LC18
# Finished with 1753367903 LC18
# Finished with 1753371564 LC18
# Finished with 1753385655 LC18
# Finished with 1753034787 LC18
# Finished with 1776553851 LC18
# Finished with 1779972924 LC18
# Finished with 1781333390 LC18
# Finished with 1780651267 LC18
# Finished with 1808958240 LC18
# Finished with 1809302520 LC18
# Finished with 1869300439 LC18
# Finished with 1871031444 LC18
# Finished with 1902066185 LC18
# Finished with 1934133595 LC18
# Finished with 1965168774 LC18
# Finished with 1968889019 LC18
# Finished with 1995858223 LC18
# Finished with 2058273371 LC18
# Finished with 2088629661 LC18
# Finished with 2119272595 LC18
# Finished with 2337578051 LC18
# Finished with 5812996595 LC18
# Finished with 5812996611 LC18
# Finished with 5812998072 LC18
# Finished with 5813061735 LC18
# Finished with 5813034284 LC18
# Finished with 5901204412 LC18
# Finished with 5812988294 LC18
# Finished with 5812989689 LC18
# Finished with 5812989776 LC18
# Finished with 5812991798 LC18
# Finished with 1222022960 LC20
# Finished with 1253398506 LC20
# Finished with 1254793503 LC20
# Finished with 1284779082 LC20
# Finished with 1283031294 LC20
# Finished with 1283034573 LC20
# Finished with 1315464724 LC20
# Finished with 1316158839 LC20
# Finished with 1344509330 LC20
# Finished with 1346840451 LC20
# Finished with 1347176607 LC20
# Finished with 1380206312 LC20
# Finished with 1378570483 LC20
# Finished with 1407252557 LC20
# Finished with 1408612051 LC20
# Finished with 1407853195 LC20
# Finished with 1440972629 LC20
# Finished with 1438550573 LC20
# Finished with 1469999513 LC20
# Finished with 1503677795 LC20
# Finished with 1562689878 LC20
# Finished with 1597494148 LC20
# Finished with 1688526691 LC20
# Finished with 1687844304 LC20
# Finished with 1690897627 LC20
# Finished with 1690902029 LC20
# Finished with 1690935369 LC20
# Finished with 1722954501 LC20
# Finished with 1749944256 LC20
# Finished with 1782996020 LC20
# Finished with 1808936407 LC20
# Finished with 1846113980 LC20
# Finished with 1873734612 LC20
# Finished with 1902066682 LC20
# Finished with 1935126292 LC20
# Finished with 1938175243 LC20
# Finished with 1968872215 LC20
# Finished with 1968877434 LC20
# Finished with 1966174797 LC20
# Finished with 2002976113 LC20
# Finished with 2094381099 LC20
# Finished with 2125424856 LC20
# Finished with 2185822630 LC20
# Finished with 2181730644 LC20
# Finished with 2186155295 LC20
# Finished with 2215809310 LC20
# Finished with 2310627347 LC20
# Finished with 2310627606 LC20
# Finished with 2310627904 LC20
# Finished with 2404077917 LC20
# Finished with 2403063724 LC20
# Finished with 5812999529 LC20
# Finished with 5901199267 LC20
# Finished with 5901207252 LC20
# Finished with 5812994094 LC20
# Finished with 7112579856 LC20
# Finished with 1281316775 LC21
# Finished with 1281649467 LC21
# Finished with 1281985562 LC21
# Finished with 1404783075 LC21
# Finished with 1437186918 LC21
# Finished with 1468877324 LC21
# Finished with 1468207771 LC21
# Finished with 1504086607 LC21
# Finished with 1504092028 LC21
# Finished with 1503413234 LC21
# Finished with 1503413796 LC21
# Finished with 1503413797 LC21
# Finished with 1504096262 LC21
# Finished with 1504096339 LC21
# Finished with 1503754316 LC21
# Finished with 1503754464 LC21
# Finished with 1503754543 LC21
# Finished with 1503754677 LC21
# Finished with 1503755184 LC21
# Finished with 1503418436 LC21
# Finished with 1504423575 LC21
# Finished with 1504423636 LC21
# Finished with 1504765194 LC21
# Finished with 1504765248 LC21
# Finished with 1504423804 LC21
# Finished with 1504427615 LC21
# Finished with 1504427986 LC21
# Finished with 1504428057 LC21
# Finished with 1504432299 LC21
# Finished with 1529635236 LC21
# Finished with 1533083877 LC21
# Finished with 1532060472 LC21
# Finished with 1532401533 LC21
# Finished with 1532401650 LC21
# Finished with 1532401674 LC21
# Finished with 1532401727 LC21
# Finished with 1532742712 LC21
# Finished with 1534107181 LC21
# Finished with 1534447833 LC21
# Finished with 1534448646 LC21
# Finished with 1536140581 LC21
# Finished with 1535065850 LC21
# Finished with 1534784712 LC21
# Finished with 1534785094 LC21
# Finished with 1534788807 LC21
# Finished with 1535808539 LC21
# Finished with 1535462901 LC21
# Finished with 1559284412 LC21
# Finished with 1563095398 LC21
# Finished with 1589636158 LC21
# Finished with 1623719786 LC21
# Finished with 1655496596 LC21
# Finished with 1655497024 LC21
# Finished with 1686190133 LC21
# Finished with 1714795031 LC21
# Finished with 1717562249 LC21
# Finished with 1717899399 LC21
# Finished with 1750289956 LC21
# Finished with 1778916255 LC21
# Finished with 1808927915 LC21
# Finished with 1841663352 LC21
# Finished with 1872396010 LC21
# Finished with 1906137714 LC21
# Finished with 1995516734 LC21
# Finished with 2028261229 LC21
# Finished with 2089653445 LC21
# Finished with 5813060340 LC21
# Finished with 5813038156 LC21
# Finished with 5812989274 LC21
# Finished with 5813075792 LC21
# Finished with 5812990925 LC21
# Finished with 5812993222 LC21
# Finished with 5813054477 LC21
# Finished with 1313038188 LC22
# Finished with 1374438280 LC22
# Finished with 1439590350 LC22
# Finished with 1501664809 LC22
# Finished with 1563364112 LC22
# Finished with 1657940629 LC22
# Finished with 1658290299 LC22
# Finished with 1718995507 LC22
# Finished with 1719569268 LC22
# Finished with 1719332432 LC22
# Finished with 1750039535 LC22
# Finished with 1749007402 LC22
# Finished with 1749007519 LC22
# Finished with 1749020274 LC22
# Finished with 1749020373 LC22
# Finished with 1750371809 LC22
# Finished with 1750712639 LC22
# Finished with 1749343874 LC22
# Finished with 1782992460 LC22
# Finished with 1813727811 LC22
# Finished with 1813728233 LC22
# Finished with 1810645950 LC22
# Finished with 1810986443 LC22
# Finished with 1814733827 LC22
# Finished with 1845431840 LC22
# Finished with 1845431908 LC22
# Finished with 1876466986 LC22
# Finished with 1907501440 LC22
# Finished with 5813062096 LC22
# Finished with 5813033675 LC22
# Finished with 5813068615 LC22
# Finished with 5812990726 LC22
# Finished with 5813045867 LC22
# Finished with 1131011511 LC24
# Finished with 1165085220 LC24
# Finished with 1192735693 LC24
# Finished with 1192736036 LC24
# Finished with 1192739907 LC24
# Finished with 1225455907 LC24
# Finished with 1225791777 LC24
# Finished with 1254460664 LC24
# Finished with 1257508477 LC24
# Finished with 1257163007 LC24
# Finished with 1257167518 LC24
# Finished with 1257167607 LC24
# Finished with 1254801742 LC24
# Finished with 1252677095 LC24
# Finished with 1256826061 LC24
# Finished with 1256831016 LC24
# Finished with 1256831471 LC24
# Finished with 1256835915 LC24
# Finished with 1256490442 LC24
# Finished with 1256490709 LC24
# Finished with 1256490714 LC24
# Finished with 1256494439 LC24
# Finished with 1256153716 LC24
# Finished with 1282693736 LC24
# Finished with 1287856629 LC24
# Finished with 1287860853 LC24
# Finished with 1287865184 LC24
# Finished with 1287183205 LC24
# Finished with 1319574557 LC24
# Finished with 1346788757 LC24
# Finished with 1348829819 LC24
# Finished with 1349603861 LC24
# Finished with 1408535544 LC24
# Finished with 1471269906 LC24
# Finished with 1502304335 LC24
# Finished with 1502318251 LC24
# Finished with 1505753240 LC24
# Finished with 1562352871 LC24
# Finished with 1625101825 LC24
# Finished with 1658502349 LC24
# Finished with 1660198276 LC24
# Finished with 1750247044 LC24
# Finished with 1781295424 LC24
# Finished with 1808949598 LC24
# Finished with 1809273495 LC24
# Finished with 1811306906 LC24
# Finished with 1811646824 LC24
# Finished with 1877152860 LC24
# Finished with 1903397125 LC24
# Finished with 1906789614 LC24
# Finished with 1906116138 LC24
# Finished with 1938174967 LC24
# Finished with 2027890302 LC24
# Finished with 2029573063 LC24
# Finished with 2031960555 LC24
# Finished with 2059611420 LC24
# Finished with 2187515326 LC24
# Finished with 2247202730 LC24
# Finished with 2279282060 LC24
# Finished with 2280953178 LC24
# Finished with 2372697700 LC24
# Finished with 5813000058 LC24
# Finished with 5812987748 LC24
# Finished with 5813039561 LC24
# Finished with 5813045027 LC24
# Finished with 5813054063 LC24
# Finished with 977201052 LC24
# Finished with 979567244 LC24
# Finished with 1315084914 LC25
# Finished with 1344086667 LC25
# Finished with 1350268702 LC25
# Finished with 1375798493 LC25
# Finished with 1380957285 LC25
# Finished with 1381298126 LC25
# Finished with 1382002299 LC25
# Finished with 1443364051 LC25
# Finished with 1443026992 LC25
# Finished with 1498582584 LC25
# Finished with 1500953002 LC25
# Finished with 1624083046 LC25
# Finished with 1658155884 LC25
# Finished with 1748222538 LC25
# Finished with 1750929611 LC25
# Finished with 1777227052 LC25
# Finished with 1776886049 LC25
# Finished with 1875409122 LC25
# Finished with 1905429029 LC25
# Finished with 1933429987 LC25
# Finished with 1966494349 LC25
# Finished with 1967844926 LC25
# Finished with 2001633881 LC25
# Finished with 2000903820 LC25
# Finished with 2031266973 LC25
# Finished with 2088950218 LC25
# Finished with 2155418746 LC25
# Finished with 2243458832 LC25
# Finished with 2308585856 LC25
# Finished with 1161705902 LC26
# Finished with 1285167873 LC26
# Finished with 1316194019 LC26
# Finished with 1316530839 LC26
# Finished with 1316867205 LC26
# Finished with 1316534973 LC26
# Finished with 1316535138 LC26
# Finished with 1348242642 LC26
# Finished with 1347901684 LC26
# Finished with 1347901726 LC26
# Finished with 1347902152 LC26
# Finished with 1347905926 LC26
# Finished with 1347906163 LC26
# Finished with 1348916717 LC26
# Finished with 1348920548 LC26
# Finished with 1348920795 LC26
# Finished with 1348242919 LC26
# Finished with 1348247173 LC26
# Finished with 1348248235 LC26
# Finished with 1347906562 LC26
# Finished with 1348580534 LC26
# Finished with 1348584223 LC26
# Finished with 1350273443 LC26
# Finished with 1350277508 LC26
# Finished with 1349253404 LC26
# Finished with 1376134899 LC26
# Finished with 1379277446 LC26
# Finished with 1380957320 LC26
# Finished with 1411988034 LC26
# Finished with 1412320780 LC26
# Finished with 1411655369 LC26
# Finished with 1468230494 LC26
# Finished with 1475391747 LC26
# Finished with 1559979355 LC26
# Finished with 1842682322 LC26
# Finished with 1904420313 LC26
# Finished with 2121340624 LC26
# Finished with 2211737961 LC26
# Finished with 2278224718 LC26
# Finished with 5813038168 LC26
# Finished with 5813045024 LC26
# Finished with 1222696201 LC27
# Finished with 1222696284 LC27
# Finished with 1473997538 LC27
# Finished with 1501980151 LC27
# Finished with 1504700834 LC27
# Finished with 1596104906 LC27
# Finished with 1595084420 LC27
# Finished with 1629880348 LC27
# Finished with 1718227906 LC27
# Finished with 1723658004 LC27
# Finished with 1754348495 LC27
# Finished with 1752988351 LC27
# Finished with 1781981967 LC27
# Finished with 2061316365 LC27
# Finished with 2064040742 LC27
# Finished with 5813002071 LC27
# Finished with 5812992898 LC27
# Finished with 1349240911 LC29
# Finished with 1374767239 LC29
# Finished with 1408966145 LC29
# Finished with 1440670548 LC29
# Finished with 1440670595 LC29
# Finished with 1471705177 LC29
# Finished with 1502748318 LC29
# Finished with 1813727537 LC29
# Finished with 2219867226 LC29
# Finished with 5813031566 LC29
# Finished with 5812990678 LC29
# Finished with 5812992013 LC29
# Finished with 5813085201 LC29
# Finished with 5813016911 LC29
# Finished with 1312015204 LC31
# Finished with 1497205225 LC31
# Finished with 1559284164 LC31
# Finished with 1558605806 LC31
# Finished with 1684451749 LC31
# Finished with 1838615654 LC31
# Finished with 1848592019 LC31
# Finished with 1848251306 LC31
# Finished with 1869649833 LC31
# Finished with 1906499952 LC31
# Finished with 1906159372 LC31
# Finished with 1998250011 LC31
# Finished with 2028261424 LC31
# Finished with 5812999429 LC31
# Finished with 5812993245 LC31
# Finished with 1005857954 LC36
# Finished with 1005858013 LC36
# Finished with 1469278367 LC36
# Finished with 1533063011 LC36
# Finished with 1564097399 LC36
# Finished with 5812990956 LC36
# Finished with 5813054534 LC36
# Finished with 974839595 LC36
# Finished with 974839704 LC36
# Finished

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_15131/2103537015.py in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
# import skel_clean_utils file
spec = importlib.util.spec_from_file_location('skel_clean_utils', home_dir+'/util_files/skel_clean_utils.py')
skel_clean_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(skel_clean_utils)

std_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_std.csv').to_numpy()
mean_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_mean.csv').to_numpy()
betas = pd.read_csv(home_dir + '/saved_data/trivial_leaf_betas.csv').to_numpy()

for i_neuron in np.where( np.isin(neuron_quality_np[:,1], analyze_neurons) )[0]:
    t0 = time.time()
    bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    if isfile(skel_file) and not isfile(new_skel_file):
        old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
        node_classes, important_nodes = skel_clean_utils.classify_nodes(old_s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
        if node_classes is not None:
            s_pandas = pd.read_csv(skel_file)
            s_pandas = skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
            skeleton.reorient_skeleton( s_pandas, rowId = important_nodes['root node'] )

            #keep_bool = np.array([False])
            #while np.any(~keep_bool):
            s_np = s_pandas.to_numpy()
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            leaf_space, nodes = skel_clean_utils.get_is_trivial_leaf_space(bodyId, leaf_nodes, mean_vals.shape[1], s_pandas.copy())
            zscore_leaf = (leaf_space - mean_vals) / std_vals
            q_vals = np.matmul(np.append(np.ones((len(leaf_nodes),1)), zscore_leaf,axis=1), betas.T)[:,0]
            probs = 1 / (1 + np.exp(-q_vals))
            is_trivial = probs >= 0.6

            keep_bool = np.ones( len(s_np), dtype=bool )
            for node in nodes[is_trivial]:
                keep_bool[ utils.get_down_idxs(s_np, node, np.isin(s_np[:,0],branch_nodes))[:-1] ] = False
            s_pandas = pd.DataFrame( data = s_np[ keep_bool ], columns = s_pandas.columns )
            s_np = s_pandas.to_numpy()
            
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
                    
            # eliminated nodes with the same coordinate
            del_idxs = [1]
            while len(del_idxs) > 0:
                skel_coords = s_np[:,[1,2,3]]
                row_cols = np.array( [ [] for _ in range(2) ] , dtype=int).T
                for row in range( len(s_np)-1 ):
                    cols = np.where( np.all(skel_coords[row].reshape((1,3)) == skel_coords[row+1:],axis=1) )[0]
                    if len(cols) >= 2:
                        # figure out who is connected to who
                        same_coord_idxs = np.append(row,cols+row+1)
                        same_coord_nodes = s_np[same_coord_idxs,0]
                        same_coord_down_nodes = s_np[same_coord_idxs,5]
                        if np.any( np.isin( same_coord_down_nodes, same_coord_nodes) ):
                            i_idx = np.where( np.isin( same_coord_down_nodes, same_coord_nodes) )[0][0]
                            j_idx = np.where( same_coord_down_nodes[i_idx] == same_coord_nodes )[0][0]
                            assert s_np[ same_coord_idxs[i_idx], 5] == s_np[ same_coord_idxs[j_idx], 0]

                            this_row, this_col = s_np[same_coord_idxs[[i_idx,j_idx]], 0]
                            if this_row not in row_cols and this_col not in row_cols:
                                row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                    elif len(cols)==1:
                        this_row = s_np[row,0]
                        this_col = s_np[cols[0]+row+1,0]
                        if this_row not in row_cols and this_col not in row_cols:
                            row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                assert len(np.unique(row_cols)) == len(row_cols.flatten())
                del_idxs = []
                for row_node, col_node in row_cols:
                    row = np.where( s_np[:,0] == row_node )[0][0]
                    col = np.where( s_np[:,0] == col_node )[0][0]

                    assert np.all( skel_coords[row] == skel_coords[col] )
                    if s_np[row,5] == s_np[col,0] or s_np[col,5] == s_np[row,0]:
                        if s_np[row,5] == s_np[col,0]:
                            up_idx, down_idx = row, col
                        elif s_np[col,5] == s_np[row,0]:
                            down_idx, up_idx = row, col
                        assert s_np[up_idx,5] == s_np[down_idx,0]

                        if np.sum( s_np[up_idx,0] == s_np[:,5] ) > 0:
                            # connect node(s) upstream of up_idx to down_idx 
                            for idx in np.where( s_np[up_idx,0] == s_np[:,5] )[0]:
                                s_pandas.at[idx, 'link'] = s_np[down_idx,0]
                        del_idxs.append( up_idx )
                if len(del_idxs) > 0:
                    s_np = s_np[ ~np.isin( np.arange(len(s_np)), del_idxs ) ]
                    s_pandas = pd.DataFrame( data = s_np, columns = s_pandas.columns )
            assert len(s_np) == len(s_pandas)
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
            
            # change direction of theta and phi to ensure they point down the skeleton
            new_cols = np.concatenate( [np.array(s_pandas.columns)[:6], ['distance'], np.array(s_pandas.columns)[6:] ] )
            s_pandas = skel_clean_utils.append_distance( s_pandas ) # create a distance field in the dataframe
            s_pandas = s_pandas.reindex(columns=new_cols)
            s_np = s_pandas.to_numpy()
            
            frac_wrong = 0.0
            for idx in range(len(s_np)):
                xyz = np.array( utils.spherical_2_cart(1, s_np[idx,7], s_np[idx,8]) )
                xyz = xyz / np.sqrt(np.sum(xyz**2))
                if s_np[idx,5] != -1:
                    down_idx = np.where(s_np[idx,5] == s_np[:,0] )[0][0]
                    down_xyz = s_np[ down_idx, [1,2,3]] - s_np[ idx, [1,2,3] ]
                    assert np.sqrt(np.sum(down_xyz**2)) > 0
                    down_xyz = down_xyz / np.sqrt(np.sum(down_xyz**2))
                    assert np.abs( np.sum(down_xyz * xyz) ) < 1.01, f'{down_xyz}, {xyz}, {np.sum(down_xyz * xyz)}'
                    if np.sum(down_xyz * xyz) < 0:
                        # xyz is pointed in the wrong direction
                        _, theta, phi = utils.cart_2_spherical( -xyz[0], -xyz[1], -xyz[2] )
                        s_np[idx,7] = theta
                        s_np[idx,8] = phi
                        frac_wrong += 1 / len(s_np)
            node_classes, important_nodes = skel_clean_utils.classify_nodes(s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
            s_pandas['node_classes'] = node_classes
            s_pandas.to_csv(new_skel_file, index = False)
            print( f'Finished with {bodyId} {neuron_type}' )
print('Finished')

# %%
for neuron_type in config.analyze_neurons:
    num_analyzed = 0
    for i_neuron in np.where( neuron_type == neuron_quality_np[:,1] )[0]:
        bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
        new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
        num_analyzed += int( isfile(new_skel_file) )
    print( num_analyzed, np.sum( neuron_type == neuron_quality_np[:,1] ), neuron_type)
