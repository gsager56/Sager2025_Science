# %%
# % matplotlib inline
from neuprint import Client, skeleton
from neuprint import fetch_synapses, NeuronCriteria as NC, SynapseCriteria as SC
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import random
from os.path import isfile
from sklearn.linear_model import LogisticRegression
import time
from sklearn.decomposition import PCA
import statsmodels.api as sm
from scipy.spatial.distance import cdist

token_id = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdhcnJldHQuc2FnZXJAeWFsZS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hLS9BT2gxNEdpTGNqZXlHYWNnS3NPcTgzdDNfczBoTU5sQUtlTkljRzdxMkU5Rz1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgwMTAxNzUwNn0.dzq7Iy01JwSWbKq-Qvi8ov7Hwr0-ozpYeSnOsUD-Mx0"
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation
home_dir = '/Users/gs697/Research/positioning_paper'
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token=token_id)
neuron_quality = pd.read_csv(home_dir + '/saved_data/neuron_quality.csv')
neuron_quality_np = neuron_quality.to_numpy()
server = 'http://hemibrain-dvid.janelia.org'

# import utils file
spec = importlib.util.spec_from_file_location('utils', home_dir+'/util_files/utils.py')
utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(utils)

# import skel_clean_utils file
spec = importlib.util.spec_from_file_location('skel_clean_utils', home_dir+'/util_files/skel_clean_utils.py')
skel_clean_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(skel_clean_utils)

# import GLM_utils file
spec = importlib.util.spec_from_file_location('GLM_utils', home_dir+'/util_files/GLM_utils.py')
GLM_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(GLM_utils)

# import config file
spec = importlib.util.spec_from_file_location('config', home_dir+'/util_files/config.py')
config = importlib.util.module_from_spec(spec)
spec.loader.exec_module(config)

node_class_dict = config.node_class_dict
analyze_neurons  = config.analyze_neurons

# %%
# trim LC neurons

#std_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_std.csv').to_numpy()
#mean_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_mean.csv').to_numpy()
#betas = pd.read_csv(home_dir + '/saved_data/trivial_leaf_betas.csv').to_numpy()

for i_neuron in np.where( np.isin(neuron_quality_np[:,1], analyze_neurons) )[0]:
    t0 = time.time()
    bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    if isfile(skel_file) and not isfile(new_skel_file):
        old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
        node_classes, important_nodes = skel_clean_utils.classify_nodes(old_s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
        if node_classes is not None:
            s_pandas = pd.read_csv(skel_file)
            assert len(s_pandas) > 10
            s_pandas = skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
            skeleton.reorient_skeleton( s_pandas, rowId = important_nodes['root node'] )

            s_np = s_pandas.to_numpy()
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            keep_bool = np.ones( len(s_np), dtype=bool )
            for i_leaf, leaf_node in enumerate(leaf_nodes):
                leaf_idxs = utils.get_down_idxs(s_np, leaf_node, np.isin(s_np[:,0], branch_nodes))
                leaf_length = np.max( np.sqrt( np.sum( (s_np[leaf_idxs,:][:,[1,2,3]] - s_np[leaf_idxs[-1],[1,2,3]][np.newaxis,:])**2, axis=1) ) ) - s_np[leaf_idxs[-1],4]
                if leaf_length - (s_np[leaf_idxs[0],4]*2) <= (91.439 / 8):
                    keep_bool[ leaf_idxs[:-1] ] = False # this is a trivial leaf
            s_pandas = pd.DataFrame( data = s_np[ keep_bool ], columns = s_pandas.columns )
            s_np = s_pandas.to_numpy()
            
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
                    
            # eliminated nodes with the same coordinate
            del_idxs = [1]
            while len(del_idxs) > 0:
                skel_coords = s_np[:,[1,2,3]]
                row_cols = np.array( [ [] for _ in range(2) ] , dtype=int).T
                for row in range( len(s_np)-1 ):
                    cols = np.where( np.all(skel_coords[row].reshape((1,3)) == skel_coords[row+1:],axis=1) )[0]
                    if len(cols) >= 2:
                        # figure out who is connected to who
                        same_coord_idxs = np.append(row,cols+row+1)
                        same_coord_nodes = s_np[same_coord_idxs,0]
                        same_coord_down_nodes = s_np[same_coord_idxs,5]
                        if np.any( np.isin( same_coord_down_nodes, same_coord_nodes) ):
                            i_idx = np.where( np.isin( same_coord_down_nodes, same_coord_nodes) )[0][0]
                            j_idx = np.where( same_coord_down_nodes[i_idx] == same_coord_nodes )[0][0]
                            assert s_np[ same_coord_idxs[i_idx], 5] == s_np[ same_coord_idxs[j_idx], 0]

                            this_row, this_col = s_np[same_coord_idxs[[i_idx,j_idx]], 0]
                            if this_row not in row_cols and this_col not in row_cols:
                                row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                    elif len(cols)==1:
                        this_row = s_np[row,0]
                        this_col = s_np[cols[0]+row+1,0]
                        if this_row not in row_cols and this_col not in row_cols:
                            row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                assert len(np.unique(row_cols)) == len(row_cols.flatten())
                del_idxs = []
                for row_node, col_node in row_cols:
                    row = np.where( s_np[:,0] == row_node )[0][0]
                    col = np.where( s_np[:,0] == col_node )[0][0]

                    assert np.all( skel_coords[row] == skel_coords[col] )
                    if s_np[row,5] == s_np[col,0] or s_np[col,5] == s_np[row,0]:
                        if s_np[row,5] == s_np[col,0]:
                            up_idx, down_idx = row, col
                        elif s_np[col,5] == s_np[row,0]:
                            down_idx, up_idx = row, col
                        assert s_np[up_idx,5] == s_np[down_idx,0]

                        if np.sum( s_np[up_idx,0] == s_np[:,5] ) > 0:
                            # connect node(s) upstream of up_idx to down_idx 
                            for idx in np.where( s_np[up_idx,0] == s_np[:,5] )[0]:
                                s_pandas.at[idx, 'link'] = s_np[down_idx,0]
                        del_idxs.append( up_idx )
                if len(del_idxs) > 0:
                    s_np = s_np[ ~np.isin( np.arange(len(s_np)), del_idxs ) ]
                    s_pandas = pd.DataFrame( data = s_np, columns = s_pandas.columns )
            assert len(s_np) == len(s_pandas)
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
            
            # change direction of theta and phi to ensure they point down the skeleton
            new_cols = np.concatenate( [np.array(s_pandas.columns)[:6], ['distance'], np.array(s_pandas.columns)[6:] ] )
            s_pandas = skel_clean_utils.append_distance( s_pandas ) # create a distance field in the dataframe
            s_pandas = s_pandas.reindex(columns=new_cols)
            s_np = s_pandas.to_numpy()
            
            frac_wrong = 0.0
            for idx in range(len(s_np)):
                xyz = np.array( utils.spherical_2_cart(1, s_np[idx,7], s_np[idx,8]) )
                xyz = xyz / np.sqrt(np.sum(xyz**2))
                if s_np[idx,5] != -1:
                    down_idx = np.where(s_np[idx,5] == s_np[:,0] )[0][0]
                    down_xyz = s_np[ down_idx, [1,2,3]] - s_np[ idx, [1,2,3] ]
                    assert np.sqrt(np.sum(down_xyz**2)) > 0
                    down_xyz = down_xyz / np.sqrt(np.sum(down_xyz**2))
                    assert np.abs( np.sum(down_xyz * xyz) ) < 1.01, f'{down_xyz}, {xyz}, {np.sum(down_xyz * xyz)}'
                    if np.sum(down_xyz * xyz) < 0:
                        # xyz is pointed in the wrong direction
                        _, theta, phi = utils.cart_2_spherical( -xyz[0], -xyz[1], -xyz[2] )
                        s_np[idx,7] = theta
                        s_np[idx,8] = phi
                        frac_wrong += 1 / len(s_np)
            node_classes, important_nodes = skel_clean_utils.classify_nodes(s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
            if node_classes is not None:
                s_pandas['node_classes'] = node_classes
                assert len(s_pandas) > 10
                s_pandas.to_csv(new_skel_file, index = False)
                print( f'Finished with {bodyId} {neuron_type}' )
print('Finished')
# Out:
# Exception ignored in: <ssl.SSLSocket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 35024), raddr=('206.241.0.102', 443)>
# ResourceWarning: unclosed <ssl.SSLSocket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 35024), raddr=('206.241.0.102', 443)>
# Exception ignored in: <ssl.SSLSocket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 35014), raddr=('206.241.0.102', 443)>
# ResourceWarning: unclosed <ssl.SSLSocket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.22.86.239', 35014), raddr=('206.241.0.102', 443)>
# Finished

# %%
# Trim KC Neurons
compartments = np.array(["a1(R)", "a2(R)", "a3(R)", "a'1(R)", "a'2(R)", "a'3(R)", "b'1(R)", "b'2(R)",
                         "b1(R)", "b2(R)","g1(R)", "g2(R)", "g3(R)", "g4(R)", "g5(R)", 'other'])

all_bodyIds = pd.read_csv( home_dir + '/saved_data/all_bodyIds.csv' ).to_numpy()
i_neurons = np.where( np.array([neuron_type.startswith('KC') for neuron_type in all_bodyIds[:,1]]) )[0]

for i_neuron in i_neurons:
    t0 = time.time()
    bodyId, neuron_type = all_bodyIds[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    if isfile(skel_file) and not isfile(new_skel_file):
        try:
            old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
            s_pandas = pd.read_csv(skel_file)
            assert len(s_pandas) > 10
            #s_pandas = skeleton.heal_skeleton(s_pandas)
            s_pandas = skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
            skeleton.reorient_skeleton( s_pandas, use_max_radius=True )

            s_np = s_pandas.to_numpy()
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            keep_bool = np.ones( len(s_np), dtype=bool )
            for i_leaf, leaf_node in enumerate(leaf_nodes):
                leaf_idxs = utils.get_down_idxs(s_np, leaf_node, np.isin(s_np[:,0], branch_nodes))
                leaf_length = np.max( np.sqrt( np.sum( (s_np[leaf_idxs,:][:,[1,2,3]] - s_np[leaf_idxs[-1],[1,2,3]][np.newaxis,:])**2, axis=1) ) ) - s_np[leaf_idxs[-1],4]
                if leaf_length - (s_np[leaf_idxs[0],4]*2) <= (91.439 / 8):
                    keep_bool[ leaf_idxs[:-1] ] = False # this is a trivial leaf
            s_pandas = pd.DataFrame( data = s_np[ keep_bool ], columns = s_pandas.columns )
            s_np = s_pandas.to_numpy()

            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]

            # eliminated nodes with the same coordinate
            del_idxs = [1]
            while len(del_idxs) > 0:
                skel_coords = s_np[:,[1,2,3]]
                row_cols = np.array( [ [] for _ in range(2) ] , dtype=int).T
                for row in range( len(s_np)-1 ):
                    cols = np.where( np.all(skel_coords[row].reshape((1,3)) == skel_coords[row+1:],axis=1) )[0]
                    if len(cols) >= 2:
                        # figure out who is connected to who
                        same_coord_idxs = np.append(row,cols+row+1)
                        same_coord_nodes = s_np[same_coord_idxs,0]
                        same_coord_down_nodes = s_np[same_coord_idxs,5]
                        if np.any( np.isin( same_coord_down_nodes, same_coord_nodes) ):
                            i_idx = np.where( np.isin( same_coord_down_nodes, same_coord_nodes) )[0][0]
                            j_idx = np.where( same_coord_down_nodes[i_idx] == same_coord_nodes )[0][0]
                            assert s_np[ same_coord_idxs[i_idx], 5] == s_np[ same_coord_idxs[j_idx], 0]

                            this_row, this_col = s_np[same_coord_idxs[[i_idx,j_idx]], 0]
                            if this_row not in row_cols and this_col not in row_cols:
                                row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                    elif len(cols)==1:
                        this_row = s_np[row,0]
                        this_col = s_np[cols[0]+row+1,0]
                        if this_row not in row_cols and this_col not in row_cols:
                            row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                assert len(np.unique(row_cols)) == len(row_cols.flatten())
                del_idxs = []
                for row_node, col_node in row_cols:
                    row = np.where( s_np[:,0] == row_node )[0][0]
                    col = np.where( s_np[:,0] == col_node )[0][0]

                    assert np.all( skel_coords[row] == skel_coords[col] )
                    if s_np[row,5] == s_np[col,0] or s_np[col,5] == s_np[row,0]:
                        if s_np[row,5] == s_np[col,0]:
                            up_idx, down_idx = row, col
                        elif s_np[col,5] == s_np[row,0]:
                            down_idx, up_idx = row, col
                        assert s_np[up_idx,5] == s_np[down_idx,0]

                        if np.sum( s_np[up_idx,0] == s_np[:,5] ) > 0:
                            # connect node(s) upstream of up_idx to down_idx 
                            for idx in np.where( s_np[up_idx,0] == s_np[:,5] )[0]:
                                s_pandas.at[idx, 'link'] = s_np[down_idx,0]
                        del_idxs.append( up_idx )
                if len(del_idxs) > 0:
                    s_np = s_np[ ~np.isin( np.arange(len(s_np)), del_idxs ) ]
                    s_pandas = pd.DataFrame( data = s_np, columns = s_pandas.columns )
            assert len(s_np) == len(s_pandas)

            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]

            # change direction of theta and phi to ensure they point down the skeleton
            new_cols = np.concatenate( [np.array(s_pandas.columns)[:6], ['distance'], np.array(s_pandas.columns)[6:] ] )
            s_pandas = skel_clean_utils.append_distance( s_pandas ) # create a distance field in the dataframe
            s_pandas = s_pandas.reindex(columns=new_cols)
            s_np = s_pandas.to_numpy()

            frac_wrong = 0.0
            for idx in range(len(s_np)):
                xyz = np.array( utils.spherical_2_cart(1, s_np[idx,7], s_np[idx,8]) )
                xyz = xyz / np.sqrt(np.sum(xyz**2))
                if s_np[idx,5] != -1:
                    down_idx = np.where(s_np[idx,5] == s_np[:,0] )[0][0]
                    down_xyz = s_np[ down_idx, [1,2,3]] - s_np[ idx, [1,2,3] ]
                    assert np.sqrt(np.sum(down_xyz**2)) > 0
                    down_xyz = down_xyz / np.sqrt(np.sum(down_xyz**2))
                    assert np.abs( np.sum(down_xyz * xyz) ) < 1.01, f'{down_xyz}, {xyz}, {np.sum(down_xyz * xyz)}'
                    if np.sum(down_xyz * xyz) < 0:
                        # xyz is pointed in the wrong direction
                        _, theta, phi = utils.cart_2_spherical( -xyz[0], -xyz[1], -xyz[2] )
                        s_np[idx,7] = theta
                        s_np[idx,8] = phi
                        frac_wrong += 1 / len(s_np)
            # get subcompartments
            coords_roi = fetch_synapses(NC(bodyId=bodyId), SC(primary_only=False, type='pre'))[['x','y','z','roi']].drop_duplicates()
            coords_roi = coords_roi.iloc[ np.where( np.isin(coords_roi['roi'].to_numpy(), compartments) )[0] ]
            dist_matrix = cdist(s_np[:,[1,2,3]], coords_roi[['x','y','z']].to_numpy())

            comps = coords_roi['roi'].to_numpy()[ np.argmin(dist_matrix,axis=1) ]
            comps[ np.min(dist_matrix,axis=1) * (8/1000) > 5 ] = 'other'
            s_pandas['node_comps'] = comps
            assert len(s_pandas) > 10
            s_pandas.to_csv(new_skel_file, index = False)
            print( f'Finished with {bodyId} {neuron_type}' )
        except:
            print(f'Could Not Analyze {bodyId} {neuron_type}' )
print('Finished')
# Out:
# Finished with 1001453586 KCa'b'-ap1
# Finished with 1003474104 KCa'b'-ap1
# Finished with 1036563762 KCa'b'-ap1
# Finished with 1018510191 KCa'b'-ap1
# Finished with 1049549402 KCa'b'-ap1
# Finished with 1049549412 KCa'b'-ap1
# Could Not Analyze 1080579786 KCa'b'-ap1
# Finished with 1080579985 KCa'b'-ap1
# Finished with 1111947403 KCa'b'-ap1
# Finished with 1170326256 KCa'b'-ap1
# Could Not Analyze 1169999059 KCa'b'-ap1
# Finished with 1201028519 KCa'b'-ap1
# Finished with 1201032707 KCa'b'-ap1
# Finished with 488179878 KCa'b'-ap1
# Finished with 487834111 KCa'b'-ap1
# Could Not Analyze 487834131 KCa'b'-ap1
# Could Not Analyze 487834179 KCa'b'-ap1
# Finished with 519206240 KCa'b'-ap1
# Finished with 519210172 KCa'b'-ap1
# Finished with 519214622 KCa'b'-ap1
# Finished with 519214895 KCa'b'-ap1
# Finished with 518864924 KCa'b'-ap1
# Finished with 518869459 KCa'b'-ap1
# Finished with 549899821 KCa'b'-ap1
# Could Not Analyze 549904227 KCa'b'-ap1
# Could Not Analyze 5813021805 KCa'b'-ap1
# Could Not Analyze 5813021808 KCa'b'-ap1
# Could Not Analyze 5813021809 KCa'b'-ap1
# Finished with 5813021822 KCa'b'-ap1
# Could Not Analyze 5812981164 KCa'b'-ap1
# Finished with 5812981339 KCa'b'-ap1
# Finished with 5812981341 KCa'b'-ap1
# Could Not Analyze 5812981348 KCa'b'-ap1
# Finished with 5813057867 KCa'b'-ap1
# Finished with 5813061597 KCa'b'-ap1
# Finished with 5813110459 KCa'b'-ap1
# Could Not Analyze 5813111042 KCa'b'-ap1
# Finished with 5813112511 KCa'b'-ap1
# Finished with 5813062565 KCa'b'-ap1
# Finished with 5813064427 KCa'b'-ap1
# Could Not Analyze 5812981858 KCa'b'-ap1
# Finished with 5812983571 KCa'b'-ap1
# Finished with 5812983645 KCa'b'-ap1
# Could Not Analyze 5812983646 KCa'b'-ap1
# Finished with 5812983903 KCa'b'-ap1
# Could Not Analyze 5813032876 KCa'b'-ap1
# Finished with 5813032887 KCa'b'-ap1
# Finished with 5813068984 KCa'b'-ap1
# Finished with 580934661 KCa'b'-ap1
# Could Not Analyze 580947602 KCa'b'-ap1
# Finished with 5813078323 KCa'b'-ap1
# Finished with 5813078679 KCa'b'-ap1
# Could Not Analyze 5813084505 KCa'b'-ap1
# Finished with 5813020041 KCa'b'-ap1
# Could Not Analyze 5813020061 KCa'b'-ap1
# Finished with 723508068 KCa'b'-ap1
# Could Not Analyze 737491062 KCa'b'-ap1
# Finished with 768525593 KCa'b'-ap1
# Could Not Analyze 799901370 KCa'b'-ap1
# Finished with 816613438 KCa'b'-ap1
# Finished with 831273286 KCa'b'-ap1
# Finished with 862312670 KCa'b'-ap1
# Could Not Analyze 893688605 KCa'b'-ap1
# Finished with 924723528 KCa'b'-ap1
# Finished with 1017819398 KCa'b'-ap2
# Finished with 1048854479 KCa'b'-ap2
# Could Not Analyze 1079215685 KCa'b'-ap2
# Finished with 1080566792 KCa'b'-ap2
# Finished with 1111615136 KCa'b'-ap2
# Finished with 1169661785 KCa'b'-ap2
# Finished with 1200351169 KCa'b'-ap2
# Finished with 1200683283 KCa'b'-ap2
# Could Not Analyze 1200687913 KCa'b'-ap2
# Finished with 1200700424 KCa'b'-ap2
# Finished with 1202673723 KCa'b'-ap2
# Finished with 1294465669 KCa'b'-ap2
# Could Not Analyze 1313496027 KCa'b'-ap2
# Finished with 477572961 KCa'b'-ap2
# Could Not Analyze 487489028 KCa'b'-ap2
# Finished with 487489064 KCa'b'-ap2
# Could Not Analyze 486815976 KCa'b'-ap2
# Could Not Analyze 517850316 KCa'b'-ap2
# Finished with 518528152 KCa'b'-ap2
# Finished with 518187118 KCa'b'-ap2
# Finished with 549908737 KCa'b'-ap2
# Finished with 548885313 KCa'b'-ap2
# Finished with 548885407 KCa'b'-ap2
# Could Not Analyze 549567614 KCa'b'-ap2
# Could Not Analyze 549222167 KCa'b'-ap2
# Finished with 549226277 KCa'b'-ap2
# Finished with 5813021736 KCa'b'-ap2
# Finished with 5813021748 KCa'b'-ap2
# Finished with 5813021766 KCa'b'-ap2
# Finished with 5813021779 KCa'b'-ap2
# Finished with 5813021806 KCa'b'-ap2
# Finished with 5813022117 KCa'b'-ap2
# Finished with 5813056300 KCa'b'-ap2
# Finished with 5813056313 KCa'b'-ap2
# Finished with 5813056390 KCa'b'-ap2
# Finished with 5812981068 KCa'b'-ap2
# Finished with 5812981270 KCa'b'-ap2
# Could Not Analyze 5812981275 KCa'b'-ap2
# Could Not Analyze 5812981277 KCa'b'-ap2
# Finished with 5812981279 KCa'b'-ap2
# Could Not Analyze 5812981290 KCa'b'-ap2
# Finished with 5812981320 KCa'b'-ap2
# Finished with 5812981322 KCa'b'-ap2
# Finished with 5812981327 KCa'b'-ap2
# Finished with 5812981333 KCa'b'-ap2
# Finished with 5812981361 KCa'b'-ap2
# Finished with 5812981373 KCa'b'-ap2
# Finished with 5812981581 KCa'b'-ap2
# Finished with 5812981582 KCa'b'-ap2
# Could Not Analyze 5812981586 KCa'b'-ap2
# Finished with 5812981602 KCa'b'-ap2
# Could Not Analyze 5813058163 KCa'b'-ap2
# Finished with 5813059951 KCa'b'-ap2
# Finished with 5813060774 KCa'b'-ap2
# Finished with 5813060776 KCa'b'-ap2
# Could Not Analyze 5813063224 KCa'b'-ap2
# Finished with 5812981961 KCa'b'-ap2
# Finished with 5812982925 KCa'b'-ap2
# Finished with 5812983544 KCa'b'-ap2
# Finished with 5812983569 KCa'b'-ap2
# Could Not Analyze 5812983869 KCa'b'-ap2
# Finished with 5812983898 KCa'b'-ap2
# Finished with 5812983899 KCa'b'-ap2
# Finished with 5812984045 KCa'b'-ap2
# Finished with 5813032868 KCa'b'-ap2
# Finished with 5813032874 KCa'b'-ap2
# Could Not Analyze 5813032900 KCa'b'-ap2
# Could Not Analyze 5813033127 KCa'b'-ap2
# Finished with 5813033208 KCa'b'-ap2
# Finished with 5813067858 KCa'b'-ap2
# Finished with 5813069379 KCa'b'-ap2
# Could Not Analyze 5813077579 KCa'b'-ap2
# Finished with 5813077582 KCa'b'-ap2
# Finished with 5813077583 KCa'b'-ap2
# Could Not Analyze 580598373 KCa'b'-ap2
# Finished with 5813047676 KCa'b'-ap2
# Finished with 5813085240 KCa'b'-ap2
# Could Not Analyze 5813093111 KCa'b'-ap2
# Finished with 5813095018 KCa'b'-ap2
# Finished with 5813096260 KCa'b'-ap2
# Finished with 5813020047 KCa'b'-ap2
# Finished with 5813020052 KCa'b'-ap2
# Finished with 5813020057 KCa'b'-ap2
# Finished with 5813020271 KCa'b'-ap2
# Finished with 602808843 KCa'b'-ap2
# Finished with 662409582 KCa'b'-ap2
# Finished with 673366263 KCa'b'-ap2
# Finished with 674393414 KCa'b'-ap2
# Finished with 704759205 KCa'b'-ap2
# Finished with 737150041 KCa'b'-ap2
# Could Not Analyze 736808522 KCa'b'-ap2
# Finished with 768525608 KCa'b'-ap2
# Finished with 768525647 KCa'b'-ap2
# Finished with 768184604 KCa'b'-ap2
# Could Not Analyze 830586919 KCa'b'-ap2
# Finished with 893347461 KCa'b'-ap2
# Finished with 986793149 KCa'b'-ap2
# Finished with 1047835635 KCa'b'-m
# Could Not Analyze 1203709763 KCa'b'-m
# Could Not Analyze 1327831724 KCa'b'-m
# Finished with 1515418525 KCa'b'-m
# Could Not Analyze 487160828 KCa'b'-m
# Could Not Analyze 486837442 KCa'b'-m
# Finished with 517871837 KCa'b'-m
# Finished with 518532490 KCa'b'-m
# Finished with 548889938 KCa'b'-m
# Finished with 548894251 KCa'b'-m
# Finished with 548898403 KCa'b'-m
# Finished with 548549000 KCa'b'-m
# Finished with 548549395 KCa'b'-m
# Finished with 548552915 KCa'b'-m
# Finished with 548553494 KCa'b'-m
# Finished with 570314896 KCa'b'-m
# Finished with 5813021174 KCa'b'-m
# Finished with 5813021772 KCa'b'-m
# Finished with 5813021778 KCa'b'-m
# Finished with 5813021786 KCa'b'-m
# Finished with 5813021792 KCa'b'-m
# Finished with 5813021832 KCa'b'-m
# Finished with 5813056299 KCa'b'-m
# Could Not Analyze 5813056305 KCa'b'-m
# Could Not Analyze 5813056327 KCa'b'-m
# Finished with 5813056372 KCa'b'-m
# Could Not Analyze 579928928 KCa'b'-m
# Finished with 5812981071 KCa'b'-m
# Finished with 5812981072 KCa'b'-m
# Finished with 5812981308 KCa'b'-m
# Could Not Analyze 5812981399 KCa'b'-m
# Could Not Analyze 5812981400 KCa'b'-m
# Could Not Analyze 5812981401 KCa'b'-m
# Finished with 5812981553 KCa'b'-m
# Finished with 5812981569 KCa'b'-m
# Finished with 5812981578 KCa'b'-m
# Finished with 5812981590 KCa'b'-m
# Finished with 5813057227 KCa'b'-m
# Finished with 5813057239 KCa'b'-m
# Finished with 5813057942 KCa'b'-m
# Finished with 579583329 KCa'b'-m
# Finished with 579587796 KCa'b'-m
# Finished with 579592619 KCa'b'-m
# Finished with 5813062842 KCa'b'-m
# Could Not Analyze 5813063140 KCa'b'-m
# Finished with 5812981689 KCa'b'-m
# Could Not Analyze 5812981796 KCa'b'-m
# Finished with 5812981797 KCa'b'-m
# Finished with 5812981800 KCa'b'-m
# Finished with 5812981816 KCa'b'-m
# Finished with 5812981960 KCa'b'-m
# Finished with 5812981978 KCa'b'-m
# Finished with 5812982086 KCa'b'-m
# Finished with 5812982087 KCa'b'-m
# Finished with 5812982088 KCa'b'-m
# Finished with 5812982149 KCa'b'-m
# Finished with 5812982397 KCa'b'-m
# Finished with 5812982429 KCa'b'-m
# Finished with 5812982692 KCa'b'-m
# Could Not Analyze 5812982706 KCa'b'-m
# Finished with 5812983112 KCa'b'-m
# Finished with 5812983174 KCa'b'-m
# Finished with 5812983866 KCa'b'-m
# Finished with 5813068687 KCa'b'-m
# Finished with 5813068690 KCa'b'-m
# Finished with 5813068752 KCa'b'-m
# Finished with 5813078064 KCa'b'-m
# Finished with 5813047220 KCa'b'-m
# Finished with 5813078499 KCa'b'-m
# Finished with 5813095472 KCa'b'-m
# Finished with 611300533 KCa'b'-m
# Finished with 610968248 KCa'b'-m
# Finished with 612323667 KCa'b'-m
# Finished with 642335553 KCa'b'-m
# Finished with 661080007 KCa'b'-m
# Finished with 661407917 KCa'b'-m
# Finished with 662409505 KCa'b'-m
# Finished with 673370525 KCa'b'-m
# Finished with 673029543 KCa'b'-m
# Could Not Analyze 705082892 KCa'b'-m
# Finished with 704742082 KCa'b'-m
# Finished with 736117977 KCa'b'-m
# Finished with 768184623 KCa'b'-m
# Could Not Analyze 798528850 KCa'b'-m
# Finished with 799560834 KCa'b'-m
# Could Not Analyze 817299301 KCa'b'-m
# Finished with 799219511 KCa'b'-m
# Finished with 861630613 KCa'b'-m
# Finished with 861634934 KCa'b'-m
# Finished with 878652627 KCa'b'-m
# Finished with 923700162 KCa'b'-m
# Finished with 1016118651 KCab-c
# Finished with 1016122913 KCab-c
# Finished with 1016123127 KCab-c
# Finished with 1047157958 KCab-c
# Finished with 1046816660 KCab-c
# Finished with 1077851524 KCab-c
# Finished with 1077851551 KCab-c
# Finished with 1450011431 KCab-c
# Finished with 1451341240 KCab-c
# Finished with 301309622 KCab-c
# Finished with 301314150 KCab-c
# Finished with 301314154 KCab-c
# Finished with 301314208 KCab-c
# Finished with 301318641 KCab-c
# Finished with 331999156 KCab-c
# Finished with 332003372 KCab-c
# Finished with 332003899 KCab-c
# Finished with 332344592 KCab-c
# Finished with 332344670 KCab-c
# Finished with 332349327 KCab-c
# Finished with 332685751 KCab-c
# Finished with 332685755 KCab-c
# Finished with 332690153 KCab-c
# Finished with 363034501 KCab-c
# Finished with 363038752 KCab-c
# Finished with 363370708 KCab-c
# Finished with 363375247 KCab-c
# Finished with 363375408 KCab-c
# Could Not Analyze 363375475 KCab-c
# Finished with 363379387 KCab-c
# Finished with 363716151 KCab-c
# Finished with 363724985 KCab-c
# Finished with 363724996 KCab-c
# Finished with 363725096 KCab-c
# Finished with 364066029 KCab-c
# Finished with 394755742 KCab-c
# Finished with 394759626 KCab-c
# Finished with 425445301 KCab-c
# Finished with 477262101 KCab-c
# Finished with 507243409 KCab-c
# Finished with 538653955 KCab-c
# Finished with 5813021135 KCab-c
# Finished with 5813021411 KCab-c
# Finished with 5813021446 KCab-c
# Finished with 5813021447 KCab-c
# Finished with 5813021471 KCab-c
# Finished with 5813021989 KCab-c
# Finished with 5813021999 KCab-c
# Finished with 5813022050 KCab-c
# Finished with 5813055916 KCab-c
# Finished with 5812980370 KCab-c
# Finished with 5812980432 KCab-c
# Finished with 5812980594 KCab-c
# Could Not Analyze 5812980600 KCab-c
# Finished with 5812980799 KCab-c
# Finished with 5812980802 KCab-c
# Finished with 5812981109 KCab-c
# Finished with 5813057573 KCab-c
# Finished with 5813061044 KCab-c
# Finished with 5813027747 KCab-c
# Finished with 5813032245 KCab-c
# Finished with 5813032702 KCab-c
# Finished with 5813062830 KCab-c
# Finished with 5813063449 KCab-c
# Finished with 5901202076 KCab-c
# Finished with 5812981970 KCab-c
# Finished with 5812982520 KCab-c
# Finished with 5812982521 KCab-c
# Finished with 5812983006 KCab-c
# Finished with 5812983298 KCab-c
# Finished with 5812983309 KCab-c
# Finished with 5812983328 KCab-c
# Finished with 5812983427 KCab-c
# Finished with 5812983575 KCab-c
# Finished with 5812983576 KCab-c
# Finished with 5812983579 KCab-c
# Finished with 5813032946 KCab-c
# Finished with 5813033259 KCab-c
# Finished with 5813128857 KCab-c
# Finished with 5813081511 KCab-c
# Finished with 5813082847 KCab-c
# Finished with 5813086212 KCab-c
# Finished with 5813096281 KCab-c
# Finished with 630373425 KCab-c
# Finished with 736126563 KCab-c
# Finished with 736126717 KCab-c
# Finished with 753489735 KCab-c
# Finished with 785232629 KCab-c
# Finished with 769721865 KCab-c
# Could Not Analyze 798537392 KCab-c
# Finished with 798537456 KCab-c
# Could Not Analyze 798537701 KCab-c
# Finished with 818637585 KCab-c
# Finished with 815926323 KCab-c
# Finished with 815926346 KCab-c
# Finished with 816263443 KCab-c
# Finished with 829568160 KCab-c
# Finished with 829572544 KCab-c
# Finished with 846270628 KCab-c
# Finished with 846611449 KCab-c
# Finished with 846611908 KCab-c
# Finished with 847254513 KCab-c
# Finished with 847254566 KCab-c
# Finished with 847595624 KCab-c
# Finished with 848287126 KCab-c
# Could Not Analyze 848316930 KCab-c
# Could Not Analyze 848321392 KCab-c
# Could Not Analyze 848662421 KCab-c
# Finished with 848662441 KCab-c
# Could Not Analyze 860944055 KCab-c
# Finished with 860603005 KCab-c
# Finished with 860607367 KCab-c
# Finished with 860607450 KCab-c
# Finished with 860607455 KCab-c
# Finished with 860607503 KCab-c
# Finished with 860261985 KCab-c
# Finished with 860266123 KCab-c
# Finished with 860266346 KCab-c
# Finished with 860266377 KCab-c
# Could Not Analyze 860266404 KCab-c
# Finished with 877313996 KCab-c
# Finished with 877974490 KCab-c
# Finished with 877982991 KCab-c
# Finished with 877987539 KCab-c
# Finished with 878324222 KCab-c
# Finished with 878333234 KCab-c
# Finished with 891978843 KCab-c
# Finished with 909704857 KCab-c
# Finished with 891637860 KCab-c
# Finished with 891642176 KCab-c
# Finished with 891642281 KCab-c
# Finished with 891642345 KCab-c
# Finished with 910386568 KCab-c
# Finished with 911400981 KCab-c
# Finished with 922677093 KCab-c
# Finished with 922677121 KCab-c
# Finished with 923013923 KCab-c
# Finished with 923018247 KCab-c
# Finished with 939738424 KCab-c
# Finished with 939738473 KCab-c
# Finished with 939742503 KCab-c
# Finished with 939742609 KCab-c
# Finished with 940083749 KCab-c
# Finished with 940084095 KCab-c
# Finished with 940087822 KCab-c
# Finished with 940761352 KCab-c
# Finished with 954053018 KCab-c
# Finished with 954053251 KCab-c
# Finished with 970777114 KCab-c
# Finished with 971113967 KCab-c
# Finished with 971118588 KCab-c
# Finished with 971118724 KCab-c
# Finished with 972080542 KCab-c
# Finished with 1016459595 KCab-m
# Finished with 1047157746 KCab-m
# Finished with 1046812283 KCab-m
# Finished with 1078525257 KCab-m
# Finished with 1108541296 KCab-m
# Finished with 1109223365 KCab-m
# Finished with 1139921468 KCab-m
# Finished with 1139921865 KCab-m
# Could Not Analyze 1162063500 KCab-m
# Finished with 1390618359 KCab-m
# Finished with 1420306364 KCab-m
# Finished with 1420651734 KCab-m
# Finished with 1421666260 KCab-m
# Finished with 1451695303 KCab-m
# Finished with 300968622 KCab-m
# Finished with 331662668 KCab-m
# Finished with 332003629 KCab-m
# Finished with 332003895 KCab-m
# Finished with 332007728 KCab-m
# Finished with 332008063 KCab-m
# Finished with 332008082 KCab-m
# Finished with 332340236 KCab-m
# Finished with 332344908 KCab-m
# Finished with 332353106 KCab-m
# Finished with 332353336 KCab-m
# Finished with 332353566 KCab-m
# Finished with 332689776 KCab-m
# Finished with 333030976 KCab-m
# Finished with 333031114 KCab-m
# Finished with 333039671 KCab-m
# Finished with 362693077 KCab-m
# Finished with 362693473 KCab-m
# Finished with 362701895 KCab-m
# Finished with 363029976 KCab-m
# Finished with 363030024 KCab-m
# Finished with 363034174 KCab-m
# Could Not Analyze 363034211 KCab-m
# Finished with 363034407 KCab-m
# Finished with 363038831 KCab-m
# Finished with 363042781 KCab-m
# Finished with 363371001 KCab-m
# Finished with 363384083 KCab-m
# Finished with 363384090 KCab-m
# Finished with 363384138 KCab-m
# Finished with 363387921 KCab-m
# Finished with 363716303 KCab-m
# Finished with 363716362 KCab-m
# Finished with 363725201 KCab-m
# Finished with 363725228 KCab-m
# Finished with 363729312 KCab-m
# Finished with 363729314 KCab-m
# Finished with 364061776 KCab-m
# Finished with 364070517 KCab-m
# Finished with 393736822 KCab-m
# Finished with 394064790 KCab-m
# Finished with 394069210 KCab-m
# Finished with 394073547 KCab-m
# Finished with 394077610 KCab-m
# Finished with 394401778 KCab-m
# Finished with 394414724 KCab-m
# Finished with 394414783 KCab-m
# Finished with 394418743 KCab-m
# Finished with 394755376 KCab-m
# Finished with 394764082 KCab-m
# Finished with 395105113 KCab-m
# Finished with 425436170 KCab-m
# Finished with 425104113 KCab-m
# Finished with 425104216 KCab-m
# Finished with 456820863 KCab-m
# Finished with 476545134 KCab-m
# Finished with 507260559 KCab-m
# Finished with 507592981 KCab-m
# Finished with 519223428 KCab-m
# Finished with 538282782 KCab-m
# Finished with 538308362 KCab-m
# Finished with 538908474 KCab-m
# Finished with 539249493 KCab-m
# Finished with 549916869 KCab-m
# Finished with 549917317 KCab-m
# Finished with 568635279 KCab-m
# Finished with 569002579 KCab-m
# Finished with 569313277 KCab-m
# Finished with 569317846 KCab-m
# Finished with 569943419 KCab-m
# Finished with 570288900 KCab-m
# Finished with 549572017 KCab-m
# Finished with 549576117 KCab-m
# Finished with 549576424 KCab-m
# Finished with 5813020830 KCab-m
# Finished with 5813021019 KCab-m
# Finished with 5813021277 KCab-m
# Finished with 5813021311 KCab-m
# Finished with 5813021312 KCab-m
# Could Not Analyze 5813021313 KCab-m
# Finished with 5813021314 KCab-m
# Finished with 5813021315 KCab-m
# Finished with 5813021319 KCab-m
# Finished with 5813021326 KCab-m
# Finished with 5813021400 KCab-m
# Finished with 5813021404 KCab-m
# Finished with 5813021441 KCab-m
# Finished with 5813021449 KCab-m
# Finished with 5813021463 KCab-m
# Finished with 5813021465 KCab-m
# Finished with 5813021647 KCab-m
# Finished with 5813022049 KCab-m
# Finished with 5813022054 KCab-m
# Finished with 5813022175 KCab-m
# Finished with 5813056110 KCab-m
# Finished with 5813056234 KCab-m
# Finished with 5813056395 KCab-m
# Finished with 5813099783 KCab-m
# Finished with 581293182 KCab-m
# Finished with 5812980192 KCab-m
# Finished with 5812980207 KCab-m
# Finished with 5812980212 KCab-m
# Finished with 5812980219 KCab-m
# Finished with 5812980222 KCab-m
# Finished with 5812980369 KCab-m
# Finished with 5812980395 KCab-m
# Finished with 5812980410 KCab-m
# Finished with 5812980414 KCab-m
# Finished with 5812980438 KCab-m
# Finished with 5812980446 KCab-m
# Finished with 5812980557 KCab-m
# Finished with 5812980561 KCab-m
# Finished with 5812980593 KCab-m
# Finished with 5812980599 KCab-m
# Finished with 5812980615 KCab-m
# Finished with 5812980624 KCab-m
# Finished with 5812980787 KCab-m
# Finished with 5812980806 KCab-m
# Finished with 5812980892 KCab-m
# Finished with 5812980947 KCab-m
# Finished with 5812981039 KCab-m
# Finished with 5812981042 KCab-m
# Finished with 5812981104 KCab-m
# Finished with 5812981127 KCab-m
# Finished with 5812981390 KCab-m
# Finished with 5812981619 KCab-m
# Finished with 5813057213 KCab-m
# Finished with 5813058069 KCab-m
# Finished with 5813058106 KCab-m
# Finished with 5813106192 KCab-m
# Finished with 5813106497 KCab-m
# Finished with 5813061625 KCab-m
# Finished with 5813113782 KCab-m
# Finished with 5813114253 KCab-m
# Finished with 5813032694 KCab-m
# Finished with 5813065308 KCab-m
# Finished with 5812981667 KCab-m
# Finished with 5812981669 KCab-m
# Finished with 5812981671 KCab-m
# Finished with 5812981690 KCab-m
# Finished with 5812981853 KCab-m
# Finished with 5812981950 KCab-m
# Finished with 5812982012 KCab-m
# Finished with 5812982162 KCab-m
# Finished with 5812982177 KCab-m
# Finished with 5812982192 KCab-m
# Finished with 5812982211 KCab-m
# Finished with 5812982316 KCab-m
# Finished with 5812982372 KCab-m
# Finished with 5812982388 KCab-m
# Finished with 5812982389 KCab-m
# Finished with 5812982390 KCab-m
# Could Not Analyze 5812982426 KCab-m
# Could Not Analyze 5812982470 KCab-m
# Finished with 5812982761 KCab-m
# Finished with 5812983023 KCab-m
# Finished with 5812983028 KCab-m
# Finished with 5812983106 KCab-m
# Finished with 5812983131 KCab-m
# Finished with 5812983206 KCab-m
# Finished with 5812983272 KCab-m
# Finished with 5812983345 KCab-m
# Finished with 5812983346 KCab-m
# Finished with 5812983423 KCab-m
# Finished with 5812983455 KCab-m
# Finished with 5812983851 KCab-m
# Could Not Analyze 5812983861 KCab-m
# Finished with 5813032734 KCab-m
# Could Not Analyze 5813032759 KCab-m
# Finished with 5813033267 KCab-m
# Finished with 5813033277 KCab-m
# Finished with 5813067736 KCab-m
# Finished with 5813067761 KCab-m
# Finished with 5813067836 KCab-m
# Finished with 5813067869 KCab-m
# Finished with 580951922 KCab-m
# Finished with 5813071406 KCab-m
# Finished with 5813042616 KCab-m
# Finished with 580610916 KCab-m
# Finished with 580611301 KCab-m
# Finished with 5813079174 KCab-m
# Finished with 5813080254 KCab-m
# Finished with 5813080343 KCab-m
# Could Not Analyze 5813011555 KCab-m
# Finished with 5813083719 KCab-m
# Finished with 5813050818 KCab-m
# Finished with 5813050820 KCab-m
# Finished with 5813054643 KCab-m
# Finished with 5813087453 KCab-m
# Finished with 5813089804 KCab-m
# Finished with 5813090605 KCab-m
# Finished with 5813090861 KCab-m
# Finished with 5813091313 KCab-m
# Finished with 599674785 KCab-m
# Finished with 600011602 KCab-m
# Could Not Analyze 601319398 KCab-m
# Finished with 5813093544 KCab-m
# Finished with 5813095238 KCab-m
# Finished with 5813020274 KCab-m
# Finished with 611309194 KCab-m
# Finished with 630377642 KCab-m
# Finished with 630381662 KCab-m
# Could Not Analyze 631396453 KCab-m
# Finished with 632013356 KCab-m
# Finished with 662728826 KCab-m
# Finished with 662772373 KCab-m
# Finished with 642680853 KCab-m
# Finished with 642680881 KCab-m
# Finished with 642681035 KCab-m
# Finished with 642689607 KCab-m
# Finished with 674056647 KCab-m
# Finished with 691760950 KCab-m
# Finished with 673715784 KCab-m
# Finished with 693099064 KCab-m
# Finished with 693785633 KCab-m
# Finished with 674398014 KCab-m
# Finished with 705432922 KCab-m
# Finished with 705091521 KCab-m
# Finished with 704750665 KCab-m
# Finished with 704750766 KCab-m
# Finished with 704750842 KCab-m
# Finished with 725174424 KCab-m
# Finished with 724134138 KCab-m
# Finished with 736463614 KCab-m
# Finished with 736467526 KCab-m
# Finished with 736467640 KCab-m
# Finished with 735785459 KCab-m
# Finished with 736122569 KCab-m
# Finished with 736126732 KCab-m
# Finished with 736126746 KCab-m
# Finished with 756567539 KCab-m
# Finished with 756585129 KCab-m
# Finished with 755177787 KCab-m
# Finished with 767161652 KCab-m
# Finished with 767161677 KCab-m
# Finished with 785189156 KCab-m
# Finished with 785198372 KCab-m
# Finished with 785525736 KCab-m
# Finished with 786221078 KCab-m
# Finished with 797514653 KCab-m
# Finished with 798192115 KCab-m
# Finished with 798196389 KCab-m
# Finished with 798196454 KCab-m
# Finished with 797855394 KCab-m
# Finished with 815240159 KCab-m
# Finished with 815926332 KCab-m
# Finished with 829231385 KCab-m
# Finished with 846616159 KCab-m
# Finished with 846620287 KCab-m
# Finished with 846952407 KCab-m
# Finished with 846952683 KCab-m
# Finished with 849685478 KCab-m
# Finished with 847254536 KCab-m
# Finished with 847254581 KCab-m
# Finished with 829015629 KCab-m
# Finished with 847297982 KCab-m
# Finished with 847989021 KCab-m
# Finished with 848666776 KCab-m
# Finished with 859925004 KCab-m
# Finished with 860257495 KCab-m
# Finished with 860265987 KCab-m
# Finished with 860266062 KCab-m
# Finished with 860266309 KCab-m
# Finished with 877318574 KCab-m
# Finished with 877659583 KCab-m
# Finished with 877659673 KCab-m
# Finished with 877987901 KCab-m
# Finished with 877992236 KCab-m
# Finished with 877992303 KCab-m
# Finished with 878324438 KCab-m
# Finished with 878333333 KCab-m
# Could Not Analyze 878337317 KCab-m
# Finished with 878670047 KCab-m
# Finished with 879032295 KCab-m
# Finished with 891301315 KCab-m
# Finished with 908340253 KCab-m
# Finished with 908353540 KCab-m
# Finished with 908668522 KCab-m
# Finished with 908668556 KCab-m
# Finished with 908685688 KCab-m
# Finished with 908685859 KCab-m
# Finished with 908689934 KCab-m
# Finished with 908690107 KCab-m
# Finished with 909026561 KCab-m
# Finished with 909026992 KCab-m
# Finished with 909368173 KCab-m
# Finished with 909372586 KCab-m
# Finished with 909372602 KCab-m
# Finished with 910063154 KCab-m
# Finished with 910404284 KCab-m
# Could Not Analyze 910412830 KCab-m
# Finished with 941102504 KCab-m
# Could Not Analyze 941111195 KCab-m
# Finished with 923018290 KCab-m
# Finished with 939030036 KCab-m
# Finished with 939738364 KCab-m
# Finished with 939738399 KCab-m
# Finished with 939738477 KCab-m
# Finished with 940079253 KCab-m
# Finished with 940079568 KCab-m
# Finished with 940079771 KCab-m
# Finished with 940084011 KCab-m
# Finished with 940084060 KCab-m
# Finished with 940425106 KCab-m
# Finished with 940425232 KCab-m
# Finished with 940748411 KCab-m
# Finished with 940752707 KCab-m
# Finished with 954053261 KCab-m
# Finished with 953712141 KCab-m
# Finished with 971118202 KCab-m
# Finished with 971459227 KCab-m
# Finished with 984746802 KCab-m
# Finished with 984405805 KCab-m
# Finished with 985429128 KCab-m
# Finished with 1016805008 KCab-p
# Finished with 1034198388 KCab-p
# Could Not Analyze 1078874826 KCab-p
# Finished with 1108545472 KCab-p
# Could Not Analyze 1328505485 KCab-p
# Finished with 1387575003 KCab-p
# Finished with 1388585088 KCab-p
# Finished with 1418273110 KCab-p
# Finished with 426818061 KCab-p
# Finished with 425086839 KCab-p
# Could Not Analyze 425086851 KCab-p
# Finished with 456462835 KCab-p
# Could Not Analyze 456462919 KCab-p
# Finished with 456467162 KCab-p
# Finished with 488520820 KCab-p
# Finished with 517858947 KCab-p
# Could Not Analyze 519555690 KCab-p
# Finished with 519573128 KCab-p
# Finished with 542371432 KCab-p
# Finished with 518195738 KCab-p
# Finished with 549571627 KCab-p
# Finished with 549248200 KCab-p
# Could Not Analyze 573065577 KCab-p
# Finished with 5813021033 KCab-p
# Could Not Analyze 5813021788 KCab-p
# Finished with 5812980566 KCab-p
# Finished with 5812980792 KCab-p
# Finished with 5812980938 KCab-p
# Finished with 5812980940 KCab-p
# Finished with 5813114700 KCab-p
# Finished with 5813114971 KCab-p
# Could Not Analyze 5812981643 KCab-p
# Finished with 5812981680 KCab-p
# Finished with 5812982780 KCab-p
# Could Not Analyze 5812982782 KCab-p
# Finished with 5812983837 KCab-p
# Finished with 5813032943 KCab-p
# Finished with 5813077589 KCab-p
# Finished with 5813010617 KCab-p
# Finished with 600365719 KCab-p
# Finished with 5813091744 KCab-p
# Finished with 5813092931 KCab-p
# Finished with 611646050 KCab-p
# Finished with 611646147 KCab-p
# Finished with 642335523 KCab-p
# Could Not Analyze 642680826 KCab-p
# Finished with 642680969 KCab-p
# Could Not Analyze 704746457 KCab-p
# Could Not Analyze 704409534 KCab-p
# Finished with 767494105 KCab-p
# Could Not Analyze 799215269 KCab-p
# Finished with 799219795 KCab-p
# Finished with 829235909 KCab-p
# Finished with 861280857 KCab-p
# Finished with 861285145 KCab-p
# Finished with 940075056 KCab-p
# Finished with 1078875017 KCab-s
# Finished with 1078534091 KCab-s
# Finished with 1078534115 KCab-s
# Finished with 1108545599 KCab-s
# Could Not Analyze 1109568528 KCab-s
# Finished with 1130687130 KCab-s
# Could Not Analyze 1140603698 KCab-s
# Finished with 1170606692 KCab-s
# Finished with 1233703950 KCab-s
# Finished with 1261989183 KCab-s
# Finished with 1327494939 KCab-s
# Finished with 1327831994 KCab-s
# Finished with 1359553384 KCab-s
# Finished with 1390942076 KCab-s
# Finished with 1420966843 KCab-s
# Finished with 1449670372 KCab-s
# Finished with 331662717 KCab-s
# Finished with 331999213 KCab-s
# Finished with 332340127 KCab-s
# Finished with 333035349 KCab-s
# Finished with 362689128 KCab-s
# Finished with 362697657 KCab-s
# Could Not Analyze 362701764 KCab-s
# Finished with 362701969 KCab-s
# Finished with 363030040 KCab-s
# Finished with 363733406 KCab-s
# Finished with 394060556 KCab-s
# Finished with 394060620 KCab-s
# Could Not Analyze 394081878 KCab-s
# Finished with 394397189 KCab-s
# Finished with 394427392 KCab-s
# Finished with 425431837 KCab-s
# Finished with 393383025 KCab-s
# Finished with 425768768 KCab-s
# Finished with 425768822 KCab-s
# Finished with 426139965 KCab-s
# Could Not Analyze 426464004 KCab-s
# Finished with 426477089 KCab-s
# Finished with 424754530 KCab-s
# Finished with 425112506 KCab-s
# Finished with 456458549 KCab-s
# Finished with 455793621 KCab-s
# Finished with 455793743 KCab-s
# Finished with 455793827 KCab-s
# Finished with 457507485 KCab-s
# Finished with 456121649 KCab-s
# Finished with 456134692 KCab-s
# Finished with 488188560 KCab-s
# Finished with 488205572 KCab-s
# Finished with 488533722 KCab-s
# Finished with 487501700 KCab-s
# Finished with 487847296 KCab-s
# Finished with 519218919 KCab-s
# Finished with 519223027 KCab-s
# Finished with 519232054 KCab-s
# Finished with 519564501 KCab-s
# Could Not Analyze 519573099 KCab-s
# Finished with 519900699 KCab-s
# Finished with 519905418 KCab-s
# Finished with 518873469 KCab-s
# Finished with 518873604 KCab-s
# Finished with 518882016 KCab-s
# Finished with 550599514 KCab-s
# Finished with 569615641 KCab-s
# Finished with 550271272 KCab-s
# Finished with 550598935 KCab-s
# Finished with 5813020831 KCab-s
# Finished with 5813021301 KCab-s
# Finished with 5813021303 KCab-s
# Finished with 5813021304 KCab-s
# Finished with 5813021386 KCab-s
# Finished with 5813021399 KCab-s
# Finished with 5813021401 KCab-s
# Finished with 5813021464 KCab-s
# Finished with 5813022212 KCab-s
# Finished with 5813055889 KCab-s
# Finished with 5813055914 KCab-s
# Finished with 5813056355 KCab-s
# Finished with 5812980179 KCab-s
# Finished with 5812980351 KCab-s
# Could Not Analyze 5812980398 KCab-s
# Finished with 5812980404 KCab-s
# Finished with 5812980425 KCab-s
# Finished with 5812980444 KCab-s
# Finished with 5812980555 KCab-s
# Finished with 5812980611 KCab-s
# Finished with 5812980618 KCab-s
# Finished with 5812980768 KCab-s
# Finished with 5812980811 KCab-s
# Finished with 5812980931 KCab-s
# Could Not Analyze 5812980944 KCab-s
# Finished with 5812981086 KCab-s
# Finished with 5812981106 KCab-s
# Finished with 5812981136 KCab-s
# Finished with 5812981379 KCab-s
# Could Not Analyze 5812981607 KCab-s
# Could Not Analyze 5812981618 KCab-s
# Finished with 5813057187 KCab-s
# Finished with 5813060614 KCab-s
# Finished with 5813109913 KCab-s
# Could Not Analyze 5813110152 KCab-s
# Finished with 5813110238 KCab-s
# Finished with 5813110928 KCab-s
# Finished with 5813062850 KCab-s
# Could Not Analyze 5813065443 KCab-s
# Finished with 5812981670 KCab-s
# Finished with 5812981673 KCab-s
# Finished with 5812981679 KCab-s
# Finished with 5812981943 KCab-s
# Could Not Analyze 5812981944 KCab-s
# Finished with 5812981971 KCab-s
# Finished with 5812982374 KCab-s
# Finished with 5812982466 KCab-s
# Finished with 5812982471 KCab-s
# Finished with 5812982490 KCab-s
# Could Not Analyze 5812982514 KCab-s
# Finished with 5812982802 KCab-s
# Finished with 5812983012 KCab-s
# Could Not Analyze 5812983114 KCab-s
# Finished with 5812983213 KCab-s
# Finished with 5812983268 KCab-s
# Finished with 5812983303 KCab-s
# Finished with 5812983454 KCab-s
# Finished with 5901205770 KCab-s
# Finished with 5813035558 KCab-s
# Finished with 5813067779 KCab-s
# Could Not Analyze 5813068743 KCab-s
# Finished with 5813069114 KCab-s
# Finished with 5813078053 KCab-s
# Finished with 5813078507 KCab-s
# Finished with 5813078552 KCab-s
# Finished with 5813081797 KCab-s
# Finished with 5813082811 KCab-s
# Finished with 5813054342 KCab-s
# Finished with 5813054343 KCab-s
# Finished with 5813088058 KCab-s
# Finished with 5813088767 KCab-s
# Finished with 5813091211 KCab-s
# Could Not Analyze 581633934 KCab-s
# Finished with 600667501 KCab-s
# Finished with 5813098738 KCab-s
# Could Not Analyze 5813019763 KCab-s
# Finished with 603422422 KCab-s
# Could Not Analyze 611304789 KCab-s
# Finished with 630373497 KCab-s
# Finished with 630722830 KCab-s
# Could Not Analyze 631051012 KCab-s
# Could Not Analyze 631059587 KCab-s
# Finished with 611646132 KCab-s
# Finished with 612668833 KCab-s
# Finished with 612669205 KCab-s
# Finished with 643703819 KCab-s
# Finished with 643362770 KCab-s
# Finished with 643363111 KCab-s
# Could Not Analyze 642680823 KCab-s
# Finished with 662789529 KCab-s
# Finished with 692110379 KCab-s
# Finished with 693159855 KCab-s
# Finished with 693841929 KCab-s
# Finished with 705432638 KCab-s
# Finished with 704750475 KCab-s
# Finished with 704409742 KCab-s
# Finished with 705774051 KCab-s
# Could Not Analyze 723853340 KCab-s
# Finished with 735785541 KCab-s
# Finished with 735785583 KCab-s
# Finished with 735785741 KCab-s
# Finished with 735790008 KCab-s
# Finished with 736808904 KCab-s
# Could Not Analyze 736813212 KCab-s
# Finished with 754197850 KCab-s
# Finished with 786929029 KCab-s
# Could Not Analyze 785573850 KCab-s
# Finished with 817993932 KCab-s
# Finished with 815922095 KCab-s
# Finished with 815930761 KCab-s
# Could Not Analyze 846620223 KCab-s
# Finished with 849707224 KCab-s
# Finished with 847293869 KCab-s
# Finished with 848330091 KCab-s
# Finished with 880055173 KCab-s
# Finished with 880409455 KCab-s
# Finished with 891629070 KCab-s
# Finished with 909730907 KCab-s
# Finished with 910063307 KCab-s
# Finished with 923359312 KCab-s
# Finished with 939729237 KCab-s
# Finished with 939738376 KCab-s
# Finished with 940079170 KCab-s
# Finished with 940425171 KCab-s
# Finished with 954730964 KCab-s
# Finished with 1004514584 KCg-d
# Finished with 1004514714 KCg-d
# Finished with 1003837184 KCg-d
# Finished with 1127604950 KCg-d
# Finished with 1171617407 KCg-d
# Finished with 1171621616 KCg-d
# Finished with 1171621682 KCg-d
# Finished with 1171280441 KCg-d
# Finished with 1173417505 KCg-d
# Finished with 1191392918 KCg-d
# Finished with 1175070762 KCg-d
# Finished with 1203433388 KCg-d
# Finished with 1203769621 KCg-d
# Finished with 1203769862 KCg-d
# Finished with 1203774485 KCg-d
# Finished with 1203774508 KCg-d
# Finished with 1203779116 KCg-d
# Finished with 1203783013 KCg-d
# Finished with 1235115629 KCg-d
# Finished with 1235150293 KCg-d
# Finished with 1234472633 KCg-d
# Finished with 1237814053 KCg-d
# Finished with 1234809285 KCg-d
# Finished with 1268861712 KCg-d
# Finished with 1265852784 KCg-d
# Could Not Analyze 1267868586 KCg-d
# Finished with 1354411526 KCg-d
# Finished with 5813022232 KCg-d
# Finished with 5813022239 KCg-d
# Could Not Analyze 5813022267 KCg-d
# Finished with 5813056183 KCg-d
# Finished with 5812978878 KCg-d
# Finished with 5812979196 KCg-d
# Finished with 5812979314 KCg-d
# Finished with 5812979531 KCg-d
# Finished with 5812979532 KCg-d
# Finished with 5812979667 KCg-d
# Finished with 5813057959 KCg-d
# Finished with 5813061888 KCg-d
# Finished with 5812982020 KCg-d
# Finished with 5812982556 KCg-d
# Finished with 5812982657 KCg-d
# Finished with 5812982826 KCg-d
# Finished with 5812982877 KCg-d
# Finished with 5812983134 KCg-d
# Finished with 5812983199 KCg-d
# Finished with 5812983438 KCg-d
# Finished with 5813033086 KCg-d
# Finished with 5813033125 KCg-d
# Finished with 5813067826 KCg-d
# Finished with 5813070270 KCg-d
# Could Not Analyze 5813077575 KCg-d
# Finished with 5813077607 KCg-d
# Finished with 5813078684 KCg-d
# Finished with 5813083651 KCg-d
# Finished with 5813090997 KCg-d
# Finished with 601388689 KCg-d
# Finished with 5813093847 KCg-d
# Finished with 5813096528 KCg-d
# Could Not Analyze 631400288 KCg-d
# Finished with 631741308 KCg-d
# Finished with 632086737 KCg-d
# Finished with 632091116 KCg-d
# Finished with 632764978 KCg-d
# Finished with 663130304 KCg-d
# Finished with 664511977 KCg-d
# Finished with 722463321 KCg-d
# Finished with 722467714 KCg-d
# Could Not Analyze 722471825 KCg-d
# Finished with 723508086 KCg-d
# Finished with 723508095 KCg-d
# Could Not Analyze 756196541 KCg-d
# Finished with 756601858 KCg-d
# Finished with 753506746 KCg-d
# Finished with 754473844 KCg-d
# Finished with 754884149 KCg-d
# Finished with 784533172 KCg-d
# Finished with 784541732 KCg-d
# Finished with 815222743 KCg-d
# Finished with 815568065 KCg-d
# Could Not Analyze 846602958 KCg-d
# Finished with 943118619 KCg-d
# Finished with 974843892 KCg-d
# Finished with 973816592 KCg-d
# Finished with 1004527691 KCg-m
# Finished with 1005179264 KCg-m
# Finished with 1003474283 KCg-m
# Finished with 1003478461 KCg-m
# Finished with 1036559440 KCg-m
# Finished with 1036559490 KCg-m
# Finished with 1035557785 KCg-m
# Could Not Analyze 1035562328 KCg-m
# Finished with 1068272038 KCg-m
# Finished with 1068276312 KCg-m
# Finished with 1068613227 KCg-m
# Finished with 1068613231 KCg-m
# Could Not Analyze 1068617431 KCg-m
# Finished with 1068954391 KCg-m
# Finished with 1068958593 KCg-m
# Finished with 1068958652 KCg-m
# Finished with 1069295816 KCg-m
# Finished with 1069295830 KCg-m
# Could Not Analyze 1067598881 KCg-m
# Finished with 1097265345 KCg-m
# Finished with 1080580151 KCg-m
# Finished with 1100675450 KCg-m
# Finished with 1100675497 KCg-m
# Finished with 1101012503 KCg-m
# Finished with 1110937445 KCg-m
# Finished with 1110985490 KCg-m
# Finished with 1129323248 KCg-m
# Finished with 1141972158 KCg-m
# Could Not Analyze 1141976953 KCg-m
# Finished with 1141977014 KCg-m
# Finished with 1141977071 KCg-m
# Finished with 1142019737 KCg-m
# Finished with 1142019868 KCg-m
# Finished with 1142028710 KCg-m
# Finished with 1142994933 KCg-m
# Finished with 1141630854 KCg-m
# Finished with 1141636055 KCg-m
# Finished with 1143686159 KCg-m
# Finished with 1141290695 KCg-m
# Finished with 1141290835 KCg-m
# Finished with 1141674495 KCg-m
# Finished with 1141678637 KCg-m
# Finished with 1141678931 KCg-m
# Finished with 1141682748 KCg-m
# Finished with 1141687352 KCg-m
# Finished with 1141691881 KCg-m
# Finished with 1141337518 KCg-m
# Could Not Analyze 1141337629 KCg-m
# Finished with 1141337663 KCg-m
# Finished with 1141337757 KCg-m
# Could Not Analyze 1141342260 KCg-m
# Finished with 1141346217 KCg-m
# Finished with 1141346308 KCg-m
# Finished with 1141346462 KCg-m
# Finished with 1141006088 KCg-m
# Finished with 1141009899 KCg-m
# Finished with 1141010036 KCg-m
# Finished with 1142658717 KCg-m
# Finished with 1142706421 KCg-m
# Finished with 1143332046 KCg-m
# Finished with 1143340753 KCg-m
# Finished with 1161731111 KCg-m
# Finished with 1142356511 KCg-m
# Could Not Analyze 1165465632 KCg-m
# Finished with 1164113870 KCg-m
# Finished with 1173054679 KCg-m
# Finished with 1173063302 KCg-m
# Finished with 1173072129 KCg-m
# Finished with 1171704378 KCg-m
# Finished with 1172665846 KCg-m
# Finished with 1172670463 KCg-m
# Finished with 1174384118 KCg-m
# Finished with 1172704683 KCg-m
# Finished with 1172713514 KCg-m
# Finished with 1172730733 KCg-m
# Finished with 1173732234 KCg-m
# Finished with 1173745220 KCg-m
# Finished with 1173745411 KCg-m
# Could Not Analyze 1172363878 KCg-m
# Finished with 1172372291 KCg-m
# Finished with 1172372382 KCg-m
# Finished with 1173391076 KCg-m
# Finished with 1174712037 KCg-m
# Finished with 1174077762 KCg-m
# Finished with 1173408617 KCg-m
# Finished with 1172044382 KCg-m
# Finished with 1172053274 KCg-m
# Finished with 1202737975 KCg-m
# Finished with 1204076441 KCg-m
# Finished with 1203420037 KCg-m
# Finished with 1202410042 KCg-m
# Finished with 1204443547 KCg-m
# Could Not Analyze 1204447548 KCg-m
# Finished with 1204775735 KCg-m
# Finished with 1204784216 KCg-m
# Finished with 1224137476 KCg-m
# Finished with 1236816635 KCg-m
# Finished with 1236073998 KCg-m
# Finished with 1232654731 KCg-m
# Could Not Analyze 1265157632 KCg-m
# Finished with 1267164975 KCg-m
# Finished with 1297202769 KCg-m
# Finished with 1297556652 KCg-m
# Finished with 354775482 KCg-m
# Finished with 354779890 KCg-m
# Finished with 415494049 KCg-m
# Finished with 415511327 KCg-m
# Finished with 415835070 KCg-m
# Could Not Analyze 415835178 KCg-m
# Finished with 415848195 KCg-m
# Finished with 415848228 KCg-m
# Finished with 415852518 KCg-m
# Finished with 415908516 KCg-m
# Finished with 416189410 KCg-m
# Finished with 416189500 KCg-m
# Finished with 416508862 KCg-m
# Finished with 416837168 KCg-m
# Finished with 385132611 KCg-m
# Finished with 385158577 KCg-m
# Finished with 446848967 KCg-m
# Finished with 446883390 KCg-m
# Finished with 447219992 KCg-m
# Finished with 447224575 KCg-m
# Finished with 477900945 KCg-m
# Finished with 477900959 KCg-m
# Finished with 477909602 KCg-m
# Finished with 477909679 KCg-m
# Finished with 477909698 KCg-m
# Finished with 478250407 KCg-m
# Finished with 478250482 KCg-m
# Finished with 508599181 KCg-m
# Finished with 508599194 KCg-m
# Finished with 508599211 KCg-m
# Finished with 508599271 KCg-m
# Finished with 508599276 KCg-m
# Finished with 508616471 KCg-m
# Finished with 508935964 KCg-m
# Finished with 508939879 KCg-m
# Finished with 508939914 KCg-m
# Finished with 508940291 KCg-m
# Finished with 508949033 KCg-m
# Finished with 509264220 KCg-m
# Finished with 540730639 KCg-m
# Finished with 540730657 KCg-m
# Finished with 538602138 KCg-m
# Finished with 538951958 KCg-m
# Finished with 539949478 KCg-m
# Finished with 539949536 KCg-m
# Finished with 539975118 KCg-m
# Could Not Analyze 539983731 KCg-m
# Finished with 540389646 KCg-m
# Could Not Analyze 540389734 KCg-m
# Finished with 569650323 KCg-m
# Finished with 569999973 KCg-m
# Finished with 570327880 KCg-m
# Finished with 570336412 KCg-m
# Could Not Analyze 570336487 KCg-m
# Finished with 570643102 KCg-m
# Finished with 570643109 KCg-m
# Finished with 570742510 KCg-m
# Finished with 570742599 KCg-m
# Finished with 570997147 KCg-m
# Finished with 571424323 KCg-m
# Finished with 571424650 KCg-m
# Finished with 571778433 KCg-m
# Finished with 5813021273 KCg-m
# Finished with 5813021275 KCg-m
# Finished with 5813021289 KCg-m
# Finished with 5813021296 KCg-m
# Finished with 5813021341 KCg-m
# Finished with 5813021363 KCg-m
# Finished with 5813021379 KCg-m
# Finished with 5813021382 KCg-m
# Finished with 5813021415 KCg-m
# Finished with 5813021469 KCg-m
# Finished with 5813021659 KCg-m
# Finished with 5813021865 KCg-m
# Finished with 5813022060 KCg-m
# Finished with 5813022119 KCg-m
# Finished with 5813022207 KCg-m
# Finished with 5813022352 KCg-m
# Finished with 5813055923 KCg-m
# Could Not Analyze 5813056120 KCg-m
# Finished with 5813056121 KCg-m
# Finished with 5813056383 KCg-m
# Finished with 5813099399 KCg-m
# Finished with 5813102642 KCg-m
# Finished with 5812979015 KCg-m
# Finished with 5812979016 KCg-m
# Finished with 5812979069 KCg-m
# Finished with 5812979128 KCg-m
# Finished with 5812979175 KCg-m
# Finished with 5812979176 KCg-m
# Could Not Analyze 5812979177 KCg-m
# Finished with 5812979187 KCg-m
# Finished with 5812979188 KCg-m
# Finished with 5812979191 KCg-m
# Finished with 5812979197 KCg-m
# Finished with 5812979371 KCg-m
# Finished with 5812979408 KCg-m
# Finished with 5812980386 KCg-m
# Finished with 5812980537 KCg-m
# Could Not Analyze 5812980579 KCg-m
# Finished with 5812980580 KCg-m
# Finished with 5812980588 KCg-m
# Finished with 5812980638 KCg-m
# Finished with 5812980796 KCg-m
# Finished with 5812980813 KCg-m
# Finished with 5812980934 KCg-m
# Finished with 5812980973 KCg-m
# Finished with 5812980992 KCg-m
# Finished with 5812981038 KCg-m
# Finished with 5812981141 KCg-m
# Finished with 5812981142 KCg-m
# Finished with 5812981148 KCg-m
# Finished with 5812981153 KCg-m
# Finished with 5812981154 KCg-m
# Finished with 5812981160 KCg-m
# Finished with 5812981227 KCg-m
# Finished with 5812981441 KCg-m
# Finished with 5812981616 KCg-m
# Finished with 5813057191 KCg-m
# Finished with 5813057210 KCg-m
# Finished with 5813057468 KCg-m
# Finished with 5813057869 KCg-m
# Finished with 5813057956 KCg-m
# Finished with 5813104095 KCg-m
# Finished with 5813104096 KCg-m
# Finished with 5813027400 KCg-m
# Could Not Analyze 5813027460 KCg-m
# Finished with 5813060798 KCg-m
# Finished with 5813060799 KCg-m
# Finished with 5813060811 KCg-m
# Finished with 5813110639 KCg-m
# Finished with 5813027704 KCg-m
# Finished with 5813032541 KCg-m
# Finished with 5813032552 KCg-m
# Finished with 5813062617 KCg-m
# Finished with 5813062637 KCg-m
# Finished with 5813064793 KCg-m
# Finished with 5812981703 KCg-m
# Could Not Analyze 5812981706 KCg-m
# Finished with 5812981717 KCg-m
# Finished with 5812981932 KCg-m
# Finished with 5812981951 KCg-m
# Finished with 5812981986 KCg-m
# Finished with 5812981990 KCg-m
# Finished with 5812982017 KCg-m
# Finished with 5812982154 KCg-m
# Finished with 5812982205 KCg-m
# Finished with 5812982216 KCg-m
# Finished with 5812982252 KCg-m
# Finished with 5812982273 KCg-m
# Finished with 5812982328 KCg-m
# Could Not Analyze 5812982371 KCg-m
# Finished with 5812982403 KCg-m
# Finished with 5812982421 KCg-m
# Could Not Analyze 5812982422 KCg-m
# Finished with 5812982436 KCg-m
# Finished with 5812982437 KCg-m
# Finished with 5812982442 KCg-m
# Finished with 5812982492 KCg-m
# Finished with 5812982505 KCg-m
# Finished with 5812982529 KCg-m
# Finished with 5812982530 KCg-m
# Finished with 5812982562 KCg-m
# Finished with 5812982577 KCg-m
# Finished with 5812982578 KCg-m
# Finished with 5812982589 KCg-m
# Finished with 5812982594 KCg-m
# Finished with 5812982602 KCg-m
# Finished with 5812982610 KCg-m
# Finished with 5812982620 KCg-m
# Finished with 5812982766 KCg-m
# Finished with 5812982803 KCg-m
# Finished with 5812982825 KCg-m
# Finished with 5812982832 KCg-m
# Finished with 5812982871 KCg-m
# Finished with 5812982872 KCg-m
# Finished with 5812982875 KCg-m
# Finished with 5812982876 KCg-m
# Finished with 5812982999 KCg-m
# Finished with 5812983003 KCg-m
# Finished with 5812983043 KCg-m
# Finished with 5812983101 KCg-m
# Finished with 5812983147 KCg-m
# Finished with 5812983152 KCg-m
# Could Not Analyze 5812983192 KCg-m
# Finished with 5812983321 KCg-m
# Finished with 5812983322 KCg-m
# Finished with 5812983323 KCg-m
# Finished with 5812983330 KCg-m
# Finished with 5812983337 KCg-m
# Finished with 5812983657 KCg-m
# Finished with 5812983658 KCg-m
# Finished with 5812983673 KCg-m
# Finished with 5813032967 KCg-m
# Finished with 5813033059 KCg-m
# Finished with 5813033144 KCg-m
# Finished with 5813033226 KCg-m
# Finished with 5812987762 KCg-m
# Finished with 5813067765 KCg-m
# Finished with 5813067792 KCg-m
# Finished with 5813067793 KCg-m
# Finished with 5813067795 KCg-m
# Finished with 5813067817 KCg-m
# Finished with 5813067833 KCg-m
# Finished with 5813068969 KCg-m
# Finished with 5813069096 KCg-m
# Finished with 5813069792 KCg-m
# Finished with 5812989173 KCg-m
# Finished with 5813070672 KCg-m
# Finished with 5813077572 KCg-m
# Finished with 5813077610 KCg-m
# Finished with 5813077613 KCg-m
# Finished with 5813047662 KCg-m
# Finished with 5813079050 KCg-m
# Finished with 5813079489 KCg-m
# Finished with 5813080766 KCg-m
# Finished with 5813083990 KCg-m
# Finished with 5813084692 KCg-m
# Finished with 5813053821 KCg-m
# Finished with 5813053878 KCg-m
# Finished with 5813053885 KCg-m
# Finished with 5813053888 KCg-m
# Finished with 5813053935 KCg-m
# Finished with 5813053937 KCg-m
# Finished with 5813054085 KCg-m
# Finished with 5813054086 KCg-m
# Finished with 5901225361 KCg-m
# Finished with 5813087798 KCg-m
# Could Not Analyze 600356751 KCg-m
# Finished with 600684832 KCg-m
# Finished with 600693904 KCg-m
# Finished with 600702348 KCg-m
# Finished with 600702483 KCg-m
# Finished with 601047826 KCg-m
# Finished with 601047827 KCg-m
# Finished with 601047853 KCg-m
# Finished with 5813093014 KCg-m
# Finished with 5813094364 KCg-m
# Finished with 5813094743 KCg-m
# Finished with 5813095915 KCg-m
# Finished with 601712754 KCg-m
# Finished with 602118253 KCg-m
# Finished with 5813019779 KCg-m
# Finished with 5813019801 KCg-m
# Finished with 5813019917 KCg-m
# Finished with 5813019982 KCg-m
# Finished with 5813020089 KCg-m
# Finished with 5813020132 KCg-m
# Finished with 602459169 KCg-m
# Finished with 602459213 KCg-m
# Finished with 5901193485 KCg-m
# Finished with 5901197726 KCg-m
# Finished with 5901198074 KCg-m
# Could Not Analyze 602809029 KCg-m
# Finished with 630381893 KCg-m
# Finished with 630722941 KCg-m
# Finished with 630727056 KCg-m
# Finished with 631051057 KCg-m
# Finished with 631055506 KCg-m
# Finished with 631064055 KCg-m
# Finished with 631396256 KCg-m
# Finished with 631396532 KCg-m
# Finished with 631400190 KCg-m
# Finished with 631400598 KCg-m
# Finished with 631400622 KCg-m
# Could Not Analyze 631400693 KCg-m
# Finished with 631422121 KCg-m
# Finished with 631422224 KCg-m
# Finished with 631733127 KCg-m
# Finished with 631737380 KCg-m
# Finished with 632048075 KCg-m
# Finished with 632069728 KCg-m
# Finished with 632069757 KCg-m
# Finished with 632069851 KCg-m
# Finished with 632397510 KCg-m
# Finished with 632397750 KCg-m
# Finished with 632397780 KCg-m
# Finished with 632397786 KCg-m
# Finished with 632397798 KCg-m
# Finished with 632402333 KCg-m
# Finished with 632734572 KCg-m
# Finished with 633144545 KCg-m
# Finished with 633148704 KCg-m
# Finished with 633148716 KCg-m
# Finished with 633148859 KCg-m
# Finished with 633149202 KCg-m
# Finished with 633498748 KCg-m
# Finished with 661084049 KCg-m
# Finished with 661395129 KCg-m
# Finished with 661399477 KCg-m
# Finished with 661408056 KCg-m
# Finished with 661430106 KCg-m
# Finished with 661740651 KCg-m
# Finished with 661757811 KCg-m
# Finished with 661766416 KCg-m
# Finished with 662081640 KCg-m
# Finished with 662081902 KCg-m
# Finished with 662085486 KCg-m
# Finished with 662107593 KCg-m
# Finished with 662418320 KCg-m
# Finished with 662452625 KCg-m
# Finished with 662461539 KCg-m
# Finished with 662754991 KCg-m
# Finished with 662763626 KCg-m
# Finished with 662767770 KCg-m
# Finished with 662806818 KCg-m
# Finished with 663091787 KCg-m
# Finished with 663134970 KCg-m
# Could Not Analyze 664141134 KCg-m
# Finished with 664184060 KCg-m
# Finished with 664187932 KCg-m
# Finished with 664188108 KCg-m
# Finished with 664188129 KCg-m
# Finished with 664188211 KCg-m
# Finished with 692093440 KCg-m
# Finished with 692119287 KCg-m
# Could Not Analyze 692430198 KCg-m
# Finished with 692810011 KCg-m
# Finished with 692818786 KCg-m
# Finished with 692818802 KCg-m
# Finished with 693099031 KCg-m
# Finished with 693099102 KCg-m
# Finished with 693133603 KCg-m
# Finished with 693500652 KCg-m
# Finished with 693785371 KCg-m
# Finished with 693837780 KCg-m
# Finished with 693841887 KCg-m
# Finished with 693846112 KCg-m
# Finished with 694524222 KCg-m
# Finished with 724522447 KCg-m
# Finished with 724867917 KCg-m
# Finished with 724876683 KCg-m
# Finished with 724885340 KCg-m
# Finished with 725200110 KCg-m
# Finished with 725217343 KCg-m
# Finished with 722450065 KCg-m
# Finished with 722467632 KCg-m
# Finished with 722471778 KCg-m
# Finished with 722821616 KCg-m
# Finished with 723153828 KCg-m
# Could Not Analyze 723158245 KCg-m
# Finished with 723167312 KCg-m
# Could Not Analyze 723495119 KCg-m
# Finished with 723848801 KCg-m
# Finished with 723849351 KCg-m
# Finished with 724142845 KCg-m
# Finished with 755851102 KCg-m
# Finished with 756196285 KCg-m
# Finished with 753839564 KCg-m
# Finished with 753847960 KCg-m
# Finished with 753852432 KCg-m
# Finished with 754188911 KCg-m
# Could Not Analyze 754188980 KCg-m
# Finished with 754202022 KCg-m
# Finished with 754206396 KCg-m
# Finished with 754547386 KCg-m
# Finished with 754870859 KCg-m
# Finished with 755229523 KCg-m
# Finished with 755544921 KCg-m
# Finished with 784204967 KCg-m
# Finished with 784895866 KCg-m
# Finished with 785232649 KCg-m
# Finished with 785914742 KCg-m
# Finished with 815580911 KCg-m
# Finished with 815909099 KCg-m
# Finished with 815922112 KCg-m
# Could Not Analyze 816276055 KCg-m
# Finished with 816276925 KCg-m
# Finished with 847297956 KCg-m
# Finished with 847302850 KCg-m
# Finished with 848692583 KCg-m
# Finished with 880383629 KCg-m
# Could Not Analyze 881057369 KCg-m
# Finished with 911755444 KCg-m
# Finished with 911759695 KCg-m
# Finished with 973146958 KCg-m
# Finished with 973151229 KCg-m
# Finished with 973488234 KCg-m
# Finished with 972128731 KCg-m
# Finished with 1224137495 KCg-s3
# Could Not Analyze 1142019878 KCg-s4
# Finished with 1392655948 KCg-t
# Finished with 5812979121 KCg-t
# Finished with 5812981046 KCg-t
# Finished with 5812981989 KCg-t
# Finished with 5812982547 KCg-t
# Finished with 630731599 KCg-t
# Could Not Analyze 785918963 KCg-t
# Finished

# %%
s_np[idx,5]
# Out:
# 9.0

# %%
skeleton.heal_skeleton(s_pandas)
# Out:
#        rowId        x        y        z     radius  link     theta       phi  \
# 0        1.0  14243.0  28757.0   7508.0  10.249013    -1  1.637130  0.336447
# 1        2.0  14250.0  28757.0   7507.0  11.834541     1  1.661717  0.118807
# 2        3.0  14267.0  28754.0   7501.0  11.807613     2  2.094351 -0.180303
# 3        4.0  14281.0  28750.0   7491.0  17.544391     3  3.099868  3.280265
# 4        5.0  14291.0  28748.0   7495.0  12.283277     4  1.820170  2.771852
# ...      ...      ...      ...      ...        ...   ...       ...       ...
# 4914  4918.0  11623.0  10712.0  16359.0  86.819227  1556  1.732895  3.023793
# 4915  4919.0  11526.0  10686.0  16313.0  51.671881  1557  1.858739  2.647709
# 4916  4920.0  11509.0  10842.0  16341.0  25.482389  4921  2.616050  2.751193
# 4917  4921.0  11604.0  10970.0  16418.0  64.601555  4922  1.768233  2.480620
# 4918  4922.0  11540.0  10839.0  16360.0  27.274351  1558  1.700657  2.202608
#
#       skel_CA      skel_SA  mito_CA  mito_SA
# 0       330.0    78.330031      0.0      0.0
# 1       440.0    86.426407      0.0      0.0
# 2       438.0    91.454386      0.0      0.0
# 3       967.0   149.156271      0.0      0.0
# 4       474.0    94.086661      0.0      0.0
# ...       ...          ...      ...      ...
# 4914  23680.0  1728.763531      0.0      0.0
# 4915   8388.0  1498.308364      0.0      0.0
# 4916   2040.0   442.036142      0.0      0.0
# 4917  13111.0  1117.360393      0.0      0.0
# 4918   2337.0   572.242739      0.0      0.0
#
# [4919 rows x 12 columns]

# %%
skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_205/1567557330.py in <module>
# ----> 1 skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
#
# ~/hemibrain/clean_mito_code/util_files/skel_clean_utils.py in heal_resampled_skel(resampled_s_pandas, bodyId)
#     294     for i in np.arange(healed_s_np.shape[0]):
#     295         node, down_node = healed_s_np[i,[0,5]]
# --> 296         idx = np.where(resampled_s_np[:,0] == node)[0][0]
#     297         while not (resampled_s_np[idx,5] in old_nodes):
#     298             idx = np.where(resampled_s_np[:,0] == resampled_s_np[idx,5])[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
resampled_s_pandas = s_pandas.copy()

# %%
    resampled_s_np = resampled_s_pandas.to_numpy()
    assert (resampled_s_np[0,5] == -1) and (resampled_s_np[0,0] == 1), 'Please do not reorient the resampled skeleton before healing'

    if np.sum(resampled_s_np[:,5] == -1) == 1: 
        assert False
        #return resampled_s_pandas

    unhealed_s_np = c.fetch_skeleton( bodyId, format='pandas', heal=False, with_distances=False).to_numpy()
    healed_s_np = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False).to_numpy()
    assert np.all( healed_s_np[:,0] == unhealed_s_np[:,0] )
    old_nodes = np.concatenate( (healed_s_np[:,0],[-1]) )

    for i in np.arange(healed_s_np.shape[0]):
        node, down_node = healed_s_np[i,[0,5]]
        idx = np.where(resampled_s_np[:,0] == node)[0][0]
        while not (resampled_s_np[idx,5] in old_nodes):
            idx = np.where(resampled_s_np[:,0] == resampled_s_np[idx,5])[0][0]
        resampled_s_np[idx,5] = down_node
    assert np.sum(resampled_s_np[:,5] == -1) == 1, 'There should be no remaining unhealead sections of the skeleton'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_205/2570250363.py in <module>
#      13 for i in np.arange(healed_s_np.shape[0]):
#      14     node, down_node = healed_s_np[i,[0,5]]
# ---> 15     idx = np.where(resampled_s_np[:,0] == node)[0][0]
#      16     while not (resampled_s_np[idx,5] in old_nodes):
#      17         idx = np.where(resampled_s_np[:,0] == resampled_s_np[idx,5])[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
node
# Out:
# 1299.0

# %%
        coords_roi = fetch_synapses(NC(bodyId=bodyId), SC(primary_only=False, type='pre'))[['x','y','z','roi']].drop_duplicates()
        coords_roi = coords_roi.iloc[ np.where( np.isin(coords_roi['roi'].to_numpy(), compartments) )[0] ]
        dist_matrix = cdist(s_np[:,[1,2,3]], coords_roi[['x','y','z']].to_numpy())
        
        comps = coords_roi['roi'].to_numpy()[ np.argmin(dist_matrix,axis=1) ]
        comps[ np.min(dist_matrix,axis=1) * (8/1000) > 5 ] = 'other'

# %%
np.unique(comps)
# Out:
# array(["a'1(R)", "a'2(R)", "a'3(R)", "b'1(R)", "b'2(R)", 'other'],
#       dtype=object)

# %%
len( pd.read_csv(skel_file) )
# Out:
# 4986

# %%
all_bodyIds = pd.read_csv( home_dir + '/saved_data/all_bodyIds.csv' ).to_numpy()
i_neurons = np.where( np.array([neuron_type.startswith('KC') for neuron_type in all_bodyIds[:,1]]) )[0]

for i_neuron in i_neurons:
    t0 = time.time()
    bodyId, neuron_type = all_bodyIds[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    
    if isfile(skel_file) and not isfile(new_skel_file):
        #old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
        s_pandas = pd.read_csv(skel_file)
        print(len(s_pandas), neuron_type)
# Out:
# 3820 KCab-c
# 2929 KCab-c
# 3144 KCab-c
# 2906 KCab-c
# 4545 KCab-c
# 3098 KCab-c
# 4311 KCab-c
# 4981 KCab-c
# 4414 KCab-c
# 3427 KCab-c
# 3233 KCab-c
# 4244 KCab-c
# 2872 KCab-c
# 4756 KCab-c
# 2989 KCab-c
# 2914 KCab-c
# 3972 KCab-c
# 4678 KCab-c
# 3576 KCab-c
# 4533 KCab-c
# 4652 KCab-c
# 3816 KCab-c
# 4775 KCab-c
# 4687 KCab-c
# 3125 KCab-c
# 3982 KCab-c
# 4683 KCab-c
# 4645 KCab-c
# 2891 KCab-c
# 2907 KCab-c
# 4335 KCab-c
# 5051 KCab-c
# 2920 KCab-c
# 3116 KCab-c
# 3314 KCab-c
# 2928 KCab-c
# 3040 KCab-c
# 2786 KCab-c
# 4555 KCab-c
# 4055 KCab-c
# 4519 KCab-c
# 3025 KCab-c
# 4453 KCab-c
# 2873 KCab-c
# 4373 KCab-c
# 4198 KCab-c
# 5096 KCab-c
# 5015 KCab-c
# 2872 KCab-c
# 5416 KCab-m
# 5576 KCab-m
# 5401 KCab-m
# 3425 KCab-m
# 5495 KCab-m
# 5845 KCab-m
# 4644 KCab-m
# 3593 KCab-m
# 4689 KCab-m
# 4737 KCab-m
# 5294 KCab-m
# 4189 KCab-m
# 4135 KCab-m
# 4905 KCab-m
# 5435 KCab-m
# 5531 KCab-m
# 5164 KCab-m
# 5437 KCab-m
# 4324 KCab-m
# 5232 KCab-m
# 4909 KCab-m
# 5401 KCab-m
# 5248 KCab-m
# 5382 KCab-m
# 5565 KCab-m
# 5529 KCab-m
# 5799 KCab-m
# 5203 KCab-m
# 5202 KCab-m
# 4946 KCab-m
# 4873 KCab-m
# 5187 KCab-m
# 4604 KCab-m
# 5234 KCab-m
# 4976 KCab-m
# 5142 KCab-m
# 5562 KCab-m
# 4975 KCab-m
# 4767 KCab-m
# 5169 KCab-m
# 5581 KCab-m
# 4566 KCab-m
# 4353 KCab-m
# 5226 KCab-m
# 4815 KCab-m
# 4437 KCab-m
# 3557 KCab-m
# 5473 KCab-m
# 4883 KCab-m
# 5384 KCab-m
# 5025 KCab-m
# 4521 KCab-m
# 5525 KCab-m
# 3127 KCab-m
# 5269 KCab-m

# %%
s_pandas
# Out:
#        rowId        x        y        z     radius    link     theta  \
# 0        1.0  17131.0  27539.0   4752.0  12.399342    -1.0  0.659214
# 1        2.0  17128.0  27543.0   4756.0  16.244350     1.0  3.888377
# 2        3.0  17100.0  27572.0   4780.0  40.789775  1990.0  3.427617
# 3     1990.0  17108.0  27564.0   4770.0  33.945276  1991.0  3.535616
# 4     1991.0  17114.0  27557.0   4761.0  28.395051     2.0  3.750424
# ...      ...      ...      ...      ...        ...     ...       ...
# 5264  5266.0  10738.0  12249.0  10535.0  15.847602  1987.0  1.972401
# 5265  1989.0  10617.0  12321.0  10536.0  19.049233  5267.0  1.626429
# 5266  5267.0  10635.0  12311.0  10534.0  17.742843  5268.0  1.504435
# 5267  5268.0  10650.0  12300.0  10534.0  17.242431  5269.0  1.618273
# 5268  5269.0  10665.0  12289.0  10532.0  16.840846  1988.0  1.328964
#
#            phi  skel_CA     skel_SA  mito_CA  mito_SA
# 0     1.962379    483.0  108.968376      0.0      0.0
# 1     1.976014    829.0  136.521325      0.0      0.0
# 2     1.802976   5227.0  346.207908      0.0      0.0
# 3     2.077203   3620.0  289.821190      0.0      0.0
# 4     1.963615   2533.0  257.679054      0.0      0.0
# ...        ...      ...         ...      ...      ...
# 5264  2.601606    789.0  128.817983      0.0      0.0
# 5265  2.676081   1140.0  149.401098      0.0      0.0
# 5266  2.529649    989.0  145.547363      0.0      0.0
# 5267  2.598474    934.0  129.844749      0.0      0.0
# 5268  2.695984    891.0  137.157729      0.0      0.0
#
# [5269 rows x 12 columns]

# %%
pd.read_csv(skel_file)
# Out:
# Empty DataFrame
# Columns: [rowId, x, y, z, radius, link, theta, phi, skel_CA, skel_SA, mito_CA, mito_SA]
# Index: []

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_4687/2103537015.py in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
    def sphere_mask(radius):
        # radius is the radius of the boolean mask
        n = radius * 2
        x, y, z = np.meshgrid( np.linspace(-1,1,n), np.linspace(-1,1,n), np.linspace(-1,1,n) )
        return x**2 + y**2 + z**2 <= 1

    subvol = [False]
    num_increment = 1
    while not np.any(subvol):
        
        num_increment = int( num_increment * 2 )
        print(dr_small*num_increment)
        if dr_small*num_increment > 200: #5/8*1000:
            # center_init is too far from any tissue, so return None
            assert False
        circ_bool = sphere_mask(dr_small*num_increment)
        min_zyx = np.flip(center_init).astype(int) - dr_small*num_increment
        max_zyx = np.flip(center_init).astype(int) + dr_small*num_increment
        box_zyx = np.array([ min_zyx, max_zyx])
        subvol = (get_subvol_any_size(box_zyx, data_instance) == bodyId) * circ_bool
        if data_instance == 'mito-objects':
            # multiply subvol by segmentation bool to get voxels that contain the mito and neuron
            subvol = (get_subvol_any_size(box_zyx, 'segmentation') == bodyId) * subvol
        if np.any(subvol):
            subvol = get_center_object(subvol)
    if dr_small == 1:
        # just return coordinates of true value closest to scenter
        body_idxs = np.array( np.where(subvol) )
        voxel_idx = np.argmin(np.sum( (body_idxs - num_increment)**2 ,axis=0))
        center = np.flip( body_idxs[:,voxel_idx] + min_zyx) # x,y,z coordinates
        return center.astype(int)

    if num_increment > 1:
        circ_bool = sphere_mask(dr_small)

    COM_idx = np.array(measurements.center_of_mass(subvol)).astype(int)
    past_subvol = np.copy(subvol); past_min_zyx = np.copy(min_zyx)
    dist_thresh = 2; count = 0
    past_COM_idx = COM_idx + 2*dist_thresh
    #old_min_zyx = min_zyx
    while np.sqrt(np.sum((COM_idx-past_COM_idx)**2)) >= dist_thresh:
        # center of mass has not converged yet
        count += 1
        past_COM_idx = np.copy(COM_idx)
        min_zyx = COM_idx + min_zyx - dr_small
        box_zyx = np.array([ min_zyx, min_zyx + 2*dr_small])
        subvol = (get_subvol_any_size(box_zyx, data_instance) == bodyId) * circ_bool
        if data_instance == 'mito-objects':
            # multiply subvol by segmentation bool to get voxels that contain the mito and neuron
            subvol = (get_subvol_any_size(box_zyx, 'segmentation') == bodyId) * subvol

        if np.any(subvol):
            subvol = get_center_object(subvol)
            past_subvol = np.copy(subvol)
            past_min_zyx = np.copy(min_zyx)
            COM_idx = np.array(measurements.center_of_mass(subvol)).astype(int)
        else:
            min_zyx = np.copy(past_min_zyx)
            subvol = np.copy(past_subvol)
        assert count < 10, 'infinite while loop detected'

    COM_idx = get_closest_true_idx(subvol, COM_idx)

    if subvol[COM_idx[0],COM_idx[1],COM_idx[2]]:
        # use COM as the center
        center = np.flip(COM_idx + min_zyx)
    else:
        # find coordinate closest to COM belonging to bodyId
        body_idxs = np.array( np.where(subvol) )
        voxel_idx = np.argmin(np.sum( (body_idxs - dr_small)**2 ,axis=0))
        center = np.flip( body_idxs[:,voxel_idx] + min_zyx) # x,y,z coordinates

    #return center.astype(int)
# Out:
# 22
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_312/1229402173.py in <module>
#      18     max_zyx = np.flip(center_init).astype(int) + dr_small*num_increment
#      19     box_zyx = np.array([ min_zyx, max_zyx])
# ---> 20     subvol = (get_subvol_any_size(box_zyx, data_instance) == bodyId) * circ_bool
#      21     if data_instance == 'mito-objects':
#      22         # multiply subvol by segmentation bool to get voxels that contain the mito and neuron
#
# NameError: name 'get_subvol_any_size' is not defined

# %%
dr_small*num_increment
# Out:
# 220

# %%
cur_coords
# Out:
# array([14788, 28498,  7066])

# %%
bodyId, neuron_type
# Out:
# (1001453586, "KCa'b'-ap1")

# %%
# import skel_clean_utils file
spec = importlib.util.spec_from_file_location('skel_clean_utils', home_dir+'/util_files/skel_clean_utils.py')
skel_clean_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(skel_clean_utils)

std_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_std.csv').to_numpy()
mean_vals = pd.read_csv(home_dir + '/saved_data/trivial_leaf_mean.csv').to_numpy()
betas = pd.read_csv(home_dir + '/saved_data/trivial_leaf_betas.csv').to_numpy()

for i_neuron in np.where( np.isin(neuron_quality_np[:,1], analyze_neurons) )[0]:
    t0 = time.time()
    bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
    skel_file = home_dir + f'/saved_neuron_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
    if isfile(skel_file) and not isfile(new_skel_file):
        old_s_pandas = c.fetch_skeleton( bodyId, format='pandas', heal=True, with_distances=False) # I will heal the skeleton later
        node_classes, important_nodes = skel_clean_utils.classify_nodes(old_s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
        if node_classes is not None:
            s_pandas = pd.read_csv(skel_file)
            s_pandas = skel_clean_utils.heal_resampled_skel(s_pandas, bodyId)
            skeleton.reorient_skeleton( s_pandas, rowId = important_nodes['root node'] )

            #keep_bool = np.array([False])
            #while np.any(~keep_bool):
            s_np = s_pandas.to_numpy()
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            leaf_space, nodes = skel_clean_utils.get_is_trivial_leaf_space(bodyId, leaf_nodes, mean_vals.shape[1], s_pandas.copy())
            zscore_leaf = (leaf_space - mean_vals) / std_vals
            q_vals = np.matmul(np.append(np.ones((len(leaf_nodes),1)), zscore_leaf,axis=1), betas.T)[:,0]
            probs = 1 / (1 + np.exp(-q_vals))
            is_trivial = probs >= 0.6

            keep_bool = np.ones( len(s_np), dtype=bool )
            for node in nodes[is_trivial]:
                keep_bool[ utils.get_down_idxs(s_np, node, np.isin(s_np[:,0],branch_nodes))[:-1] ] = False
            s_pandas = pd.DataFrame( data = s_np[ keep_bool ], columns = s_pandas.columns )
            s_np = s_pandas.to_numpy()
            
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
                    
            # eliminated nodes with the same coordinate
            del_idxs = [1]
            while len(del_idxs) > 0:
                skel_coords = s_np[:,[1,2,3]]
                row_cols = np.array( [ [] for _ in range(2) ] , dtype=int).T
                for row in range( len(s_np)-1 ):
                    cols = np.where( np.all(skel_coords[row].reshape((1,3)) == skel_coords[row+1:],axis=1) )[0]
                    if len(cols) >= 2:
                        # figure out who is connected to who
                        same_coord_idxs = np.append(row,cols+row+1)
                        same_coord_nodes = s_np[same_coord_idxs,0]
                        same_coord_down_nodes = s_np[same_coord_idxs,5]
                        if np.any( np.isin( same_coord_down_nodes, same_coord_nodes) ):
                            i_idx = np.where( np.isin( same_coord_down_nodes, same_coord_nodes) )[0][0]
                            j_idx = np.where( same_coord_down_nodes[i_idx] == same_coord_nodes )[0][0]
                            assert s_np[ same_coord_idxs[i_idx], 5] == s_np[ same_coord_idxs[j_idx], 0]

                            this_row, this_col = s_np[same_coord_idxs[[i_idx,j_idx]], 0]
                            if this_row not in row_cols and this_col not in row_cols:
                                row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                    elif len(cols)==1:
                        this_row = s_np[row,0]
                        this_col = s_np[cols[0]+row+1,0]
                        if this_row not in row_cols and this_col not in row_cols:
                            row_cols = np.append( row_cols, [[this_row,this_col]], axis=0)
                assert len(np.unique(row_cols)) == len(row_cols.flatten())
                del_idxs = []
                for row_node, col_node in row_cols:
                    row = np.where( s_np[:,0] == row_node )[0][0]
                    col = np.where( s_np[:,0] == col_node )[0][0]

                    assert np.all( skel_coords[row] == skel_coords[col] )
                    if s_np[row,5] == s_np[col,0] or s_np[col,5] == s_np[row,0]:
                        if s_np[row,5] == s_np[col,0]:
                            up_idx, down_idx = row, col
                        elif s_np[col,5] == s_np[row,0]:
                            down_idx, up_idx = row, col
                        assert s_np[up_idx,5] == s_np[down_idx,0]

                        if np.sum( s_np[up_idx,0] == s_np[:,5] ) > 0:
                            # connect node(s) upstream of up_idx to down_idx 
                            for idx in np.where( s_np[up_idx,0] == s_np[:,5] )[0]:
                                s_pandas.at[idx, 'link'] = s_np[down_idx,0]
                        del_idxs.append( up_idx )
                if len(del_idxs) > 0:
                    s_np = s_np[ ~np.isin( np.arange(len(s_np)), del_idxs ) ]
                    s_pandas = pd.DataFrame( data = s_np, columns = s_pandas.columns )
            assert len(s_np) == len(s_pandas)
            # make sure all the leaves can get to the root
            leaf_nodes, branch_nodes = utils.find_leaves_and_branches( s_np )
            for node in leaf_nodes:
                idx = np.where(s_np[:,0] == node)[0][0]
                while s_np[idx,5] != -1:
                    idx = np.where(s_np[:,0] == s_np[idx,5])[0][0]
            
            # change direction of theta and phi to ensure they point down the skeleton
            new_cols = np.concatenate( [np.array(s_pandas.columns)[:6], ['distance'], np.array(s_pandas.columns)[6:] ] )
            s_pandas = skel_clean_utils.append_distance( s_pandas ) # create a distance field in the dataframe
            s_pandas = s_pandas.reindex(columns=new_cols)
            s_np = s_pandas.to_numpy()
            
            frac_wrong = 0.0
            for idx in range(len(s_np)):
                xyz = np.array( utils.spherical_2_cart(1, s_np[idx,7], s_np[idx,8]) )
                xyz = xyz / np.sqrt(np.sum(xyz**2))
                if s_np[idx,5] != -1:
                    down_idx = np.where(s_np[idx,5] == s_np[:,0] )[0][0]
                    down_xyz = s_np[ down_idx, [1,2,3]] - s_np[ idx, [1,2,3] ]
                    assert np.sqrt(np.sum(down_xyz**2)) > 0
                    down_xyz = down_xyz / np.sqrt(np.sum(down_xyz**2))
                    assert np.abs( np.sum(down_xyz * xyz) ) < 1.01, f'{down_xyz}, {xyz}, {np.sum(down_xyz * xyz)}'
                    if np.sum(down_xyz * xyz) < 0:
                        # xyz is pointed in the wrong direction
                        _, theta, phi = utils.cart_2_spherical( -xyz[0], -xyz[1], -xyz[2] )
                        s_np[idx,7] = theta
                        s_np[idx,8] = phi
                        frac_wrong += 1 / len(s_np)
            node_classes, important_nodes = skel_clean_utils.classify_nodes(s_pandas, fetch_synapses(NC(bodyId=bodyId)), neuron_quality.iloc[i_neuron])
            s_pandas['node_classes'] = node_classes
            s_pandas.to_csv(new_skel_file, index = False)
            print( f'Finished with {bodyId} {neuron_type}' )
print('Finished')

# %%
for neuron_type in config.analyze_neurons:
    num_analyzed = 0
    for i_neuron in np.where( neuron_type == neuron_quality_np[:,1] )[0]:
        bodyId, neuron_type = neuron_quality_np[i_neuron,[0,1]]
        new_skel_file = home_dir + f'/saved_clean_skeletons/s_pandas_{bodyId}_{neuron_type}_200nm.csv'
        num_analyzed += int( isfile(new_skel_file) )
    print( num_analyzed, np.sum( neuron_type == neuron_quality_np[:,1] ), neuron_type)
